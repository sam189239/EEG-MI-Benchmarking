# %% [markdown]
# # ANN Classification of 4 class SMR dataset from BCI Competition VI dataset 2a

# %%
import mne
# %matplotlib inline
import numpy as np

# Mention the file path to the dataset
filename = "../../Data/BCICIV_2a_gdf/A01T.gdf"

raw = mne.io.read_raw_gdf(filename)

print(raw.info)
print(raw.ch_names)
# Out:
# Extracting EDF parameters from e:\566 Project\EEG-MI-Benchmarking\Data\BCICIV_2a_gdf\A01T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\contextlib.py:120: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# <Info | 8 non-empty values
#  bads: []
#  ch_names: EEG-Fz, EEG-0, EEG-1, EEG-2, EEG-3, EEG-4, EEG-5, EEG-C3, EEG-6, ...
#  chs: 25 EEG
#  custom_ref_applied: False
#  highpass: 0.5 Hz
#  lowpass: 100.0 Hz
#  meas_date: 2005-01-17 12:00:00 UTC
#  nchan: 25
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: 4 items (dict)
# >
# ['EEG-Fz', 'EEG-0', 'EEG-1', 'EEG-2', 'EEG-3', 'EEG-4', 'EEG-5', 'EEG-C3', 'EEG-6', 'EEG-Cz', 'EEG-7', 'EEG-C4', 'EEG-8', 'EEG-9', 'EEG-10', 'EEG-11', 'EEG-12', 'EEG-13', 'EEG-14', 'EEG-Pz', 'EEG-15', 'EEG-16', 'EOG-left', 'EOG-central', 'EOG-right']

# %% [markdown]
# ## Events and Epoch Extraction

# %%
# Find the events time positions
events, _ = mne.events_from_annotations(raw)

# Pre-load the data

raw.load_data()

# Filter the raw signal with a band pass filter in 7-35 Hz

raw.filter(7., 35., fir_design='firwin')

# Remove the EOG channels and pick only desired EEG channels

raw.info['bads'] += ['EOG-left', 'EOG-central', 'EOG-right']

picks = mne.pick_types(raw.info, meg=False, eeg=True, eog=False, stim=False,
                       exclude='bads')

# Extracts epochs of 3s time period from the datset into 288 events for all 4 classes

tmin, tmax = 1., 4.
# left_hand = 769,right_hand = 770,foot = 771,tongue = 772
event_id = dict({'769': 7,'770': 8,'771': 9,'772': 10})

epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=True, picks=picks,
                baseline=None, preload=True)
# Out:
# Used Annotations descriptions: ['1023', '1072', '276', '277', '32766', '768', '769', '770', '771', '772']
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 35 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 35.00 Hz
# - Upper transition bandwidth: 8.75 Hz (-6 dB cutoff frequency: 39.38 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Not setting metadata
# 288 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 751 original time points ...
# 0 bad epochs dropped

# %% [markdown]
# ### Epoch Average

# %%
# left_hand = 769,right_hand = 770,foot = 771,tongue = 772

# Left hand epoch average plot

evoked = epochs['769'].average()
print(evoked)
evoked.plot(time_unit='s')

# Right hand epoch average plot

evoked = epochs['770'].average()
print(evoked)
evoked.plot(time_unit='s')

# Foot epoch average plot

evoked = epochs['771'].average()
print(evoked)
evoked.plot(time_unit='s')

# Tongue epoch average plot

evoked = epochs['772'].average()
print(evoked)
evoked.plot(time_unit='s')
# Out:
# <Evoked | '769' (average, N=72), 1 – 4 s, baseline off, 22 ch, ~156 kB>
# <Evoked | '770' (average, N=72), 1 – 4 s, baseline off, 22 ch, ~156 kB>
# <Evoked | '771' (average, N=72), 1 – 4 s, baseline off, 22 ch, ~156 kB>
# <Evoked | '772' (average, N=72), 1 – 4 s, baseline off, 22 ch, ~156 kB>

# %% [markdown]
# ## Labels and Data

# %%
# Getting labels and changing labels from 7,8,9,10 -> 1,2,3,4
labels = epochs.events[:,-1] - 7 + 1 

data = epochs.get_data()
# Out:
# C:\Users\Sam\AppData\Local\Temp\ipykernel_34752\378257184.py:4: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   data = epochs.get_data()

# %% [markdown]
# ## Wavelet Packet Decomposition

# %%
import pywt

# signal is decomposed to level 5 with 'db4' wavelet

def wpd(X): 
    coeffs = pywt.WaveletPacket(X,'db4',mode='symmetric',maxlevel=5)
    return coeffs
             
def feature_bands(x):
    
    Bands = np.empty((8,x.shape[0],x.shape[1],30)) # 8 freq band coefficients are chosen from the range 4-32Hz
    
    for i in range(x.shape[0]):
        for ii in range(x.shape[1]):
             pos = []
             C = wpd(x[i,ii,:]) 
             pos = np.append(pos,[node.path for node in C.get_level(5, 'natural')])
             for b in range(1,9):
                 Bands[b-1,i,ii,:] = C[pos[b]].data
        
    return Bands

wpd_data = feature_bands(data)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\sam\miniconda3\lib\site-packages (2.6.0)

# %%
from mne.decoding import CSP # Common Spatial Pattern Filtering
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras import regularizers
from sklearn.model_selection import ShuffleSplit

# OneHotEncoding Labels
enc = OneHotEncoder()
X_out = enc.fit_transform(labels.reshape(-1,1)).toarray()

# Cross Validation Split
cv = ShuffleSplit(n_splits = 10, test_size = 0.2, random_state = 0)

from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

acc = []
ka = []
prec = []
recall = []

# %% [markdown]
# # Model Build

# %%
def build_classifier(num_layers = 1):
    classifier = Sequential()
    #First Layer
    classifier.add(Dense(units = 124, kernel_initializer = 'uniform', activation = 'relu', input_dim = 32, 
                         kernel_regularizer=regularizers.l2(0.01))) # L2 regularization
    classifier.add(Dropout(0.5))
    # Intermediate Layers
    for itr in range(num_layers):
        classifier.add(Dense(units = 124, kernel_initializer = 'uniform', activation = 'relu', 
                             kernel_regularizer=regularizers.l2(0.01))) # L2 regularization
        classifier.add(Dropout(0.5))   
    # Last Layer
    classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'softmax'))
    classifier.compile(optimizer = 'rmsprop' , loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return classifier

# %% [markdown]
# # 10-Fold Cross Validation

# %%
for train_idx, test_idx in cv.split(labels):
    
    Csp = [];ss = [];nn = [] # empty lists
    
    label_train, label_test = labels[train_idx], labels[test_idx]
    y_train, y_test = X_out[train_idx], X_out[test_idx]
    
    # CSP filter applied separately for all Frequency band coefficients
    
    Csp = [CSP(n_components=4, reg=None, log=True, norm_trace=False) for _ in range(8)]
    ss = preprocessing.StandardScaler()

    X_train = ss.fit_transform(np.concatenate(tuple(Csp[x].fit_transform(wpd_data[x,train_idx,:,:],label_train) for x  in range(8)),axis=-1))

    X_test = ss.transform(np.concatenate(tuple(Csp[x].transform(wpd_data[x,test_idx,:,:]) for x  in range(8)),axis=-1))
    
    nn = build_classifier()  
    
    nn.fit(X_train, y_train, batch_size = 32, epochs = 300)
    
    y_pred = nn.predict(X_test)
    pred = (y_pred == y_pred.max(axis=1)[:,None]).astype(int)

    acc.append(accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
    ka.append(cohen_kappa_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
    prec.append(precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
    recall.append(recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
# Out:
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 22 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 22 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 22 dim * 2.5e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 22 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 22 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 22 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 22 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 22 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 22 dim * 2.9e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e-05 (2.2e-16 eps * 22 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.6e-05 (2.2e-16 eps * 22 dim * 3.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.5e-05 (2.2e-16 eps * 22 dim * 3.1e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-06 (2.2e-16 eps * 22 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.4e-06 (2.2e-16 eps * 22 dim * 1.1e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-06 (2.2e-16 eps * 22 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-06 (2.2e-16 eps * 22 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-06 (2.2e-16 eps * 22 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-06 (2.2e-16 eps * 22 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.8e-06 (2.2e-16 eps * 22 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-06 (2.2e-16 eps * 22 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.2e-06 (2.2e-16 eps * 22 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-06 (2.2e-16 eps * 22 dim * 1.7e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-06 (2.2e-16 eps * 22 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-06 (2.2e-16 eps * 22 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.3e-06 (2.2e-16 eps * 22 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.8e-06 (2.2e-16 eps * 22 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.5e-06 (2.2e-16 eps * 22 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.7e-06 (2.2e-16 eps * 22 dim * 1.6e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-07 (2.2e-16 eps * 22 dim * 1.8e+08  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-07 (2.2e-16 eps * 22 dim * 1.4e+08  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-07 (2.2e-16 eps * 22 dim * 1.7e+08  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-07 (2.2e-16 eps * 22 dim * 1.4e+08  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Epoch 1/300
# 8/8 [==============================] - 1s 2ms/step - loss: 1.4824 - accuracy: 0.4739
# Epoch 2/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2893 - accuracy: 0.5696
# Epoch 3/300
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0551 - accuracy: 0.6261
# Epoch 4/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9636 - accuracy: 0.5826
# Epoch 5/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9004 - accuracy: 0.6087
# Epoch 6/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8913 - accuracy: 0.6130
# Epoch 7/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8834 - accuracy: 0.5913
# Epoch 8/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8140 - accuracy: 0.6957
# Epoch 9/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7963 - accuracy: 0.7217
# Epoch 10/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7405 - accuracy: 0.8043
# Epoch 11/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7382 - accuracy: 0.7826
# Epoch 12/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7091 - accuracy: 0.8130
# Epoch 13/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6577 - accuracy: 0.8478
# Epoch 14/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6564 - accuracy: 0.7826
# Epoch 15/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6038 - accuracy: 0.8391
# Epoch 16/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6126 - accuracy: 0.8522
# Epoch 17/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5721 - accuracy: 0.8478
# Epoch 18/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5723 - accuracy: 0.8304
# Epoch 19/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5992 - accuracy: 0.8478
# Epoch 20/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.8696
# Epoch 21/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5284 - accuracy: 0.8652
# Epoch 22/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5540 - accuracy: 0.8435
# Epoch 23/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5140 - accuracy: 0.8696
# Epoch 24/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5075 - accuracy: 0.8522
# Epoch 25/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4862 - accuracy: 0.8870
# Epoch 26/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4754 - accuracy: 0.9000
# Epoch 27/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.9000
# Epoch 28/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4546 - accuracy: 0.9043
# Epoch 29/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4499 - accuracy: 0.8957
# Epoch 30/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.8739
# Epoch 31/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.9000
# Epoch 32/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4470 - accuracy: 0.9130
# Epoch 33/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4240 - accuracy: 0.8957
# Epoch 34/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.8957
# Epoch 35/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.8913
# Epoch 36/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4313 - accuracy: 0.9000
# Epoch 37/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4219 - accuracy: 0.9000
# Epoch 38/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8870
# Epoch 39/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.9000
# Epoch 40/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4420 - accuracy: 0.8826
# Epoch 41/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.9174
# Epoch 42/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.9174
# Epoch 43/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3938 - accuracy: 0.9261
# Epoch 44/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3835 - accuracy: 0.9391
# Epoch 45/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3911 - accuracy: 0.9174
# Epoch 46/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3685 - accuracy: 0.9130
# Epoch 47/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.9000
# Epoch 48/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4052 - accuracy: 0.9261
# Epoch 49/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3977 - accuracy: 0.9000
# Epoch 50/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3592 - accuracy: 0.9130
# Epoch 51/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.9261
# Epoch 52/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3746 - accuracy: 0.9130
# Epoch 53/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.9304
# Epoch 54/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3661 - accuracy: 0.9087
# Epoch 55/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3823 - accuracy: 0.9130
# Epoch 56/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3450 - accuracy: 0.9522
# Epoch 57/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3794 - accuracy: 0.9130
# Epoch 58/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3526 - accuracy: 0.9391
# Epoch 59/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3701 - accuracy: 0.9217
# Epoch 60/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.9261
# Epoch 61/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3482 - accuracy: 0.9261
# Epoch 62/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3731 - accuracy: 0.8957
# Epoch 63/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3364 - accuracy: 0.9348
# Epoch 64/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3239 - accuracy: 0.9391
# Epoch 65/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.9435
# Epoch 66/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.9304
# Epoch 67/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3203 - accuracy: 0.9348
# Epoch 68/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3452 - accuracy: 0.9304
# Epoch 69/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.9391
# Epoch 70/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3506 - accuracy: 0.9217
# Epoch 71/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.9391
# Epoch 72/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3855 - accuracy: 0.9261
# Epoch 73/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3327 - accuracy: 0.9435
# Epoch 74/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3209 - accuracy: 0.9478
# Epoch 75/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3179 - accuracy: 0.9304
# Epoch 76/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.9348
# Epoch 77/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2964 - accuracy: 0.9652
# Epoch 78/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3037 - accuracy: 0.9478
# Epoch 79/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2871 - accuracy: 0.9565
# Epoch 80/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3090 - accuracy: 0.9304
# Epoch 81/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3153 - accuracy: 0.9261
# Epoch 82/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.9217
# Epoch 83/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3135 - accuracy: 0.9478
# Epoch 84/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3319 - accuracy: 0.9348
# Epoch 85/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3142 - accuracy: 0.9435
# Epoch 86/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3202 - accuracy: 0.9261
# Epoch 87/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3231 - accuracy: 0.9348
# Epoch 88/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3264 - accuracy: 0.9217
# Epoch 89/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3020 - accuracy: 0.9348
# Epoch 90/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3205 - accuracy: 0.9391
# Epoch 91/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3086 - accuracy: 0.9391
# Epoch 92/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3050 - accuracy: 0.9304
# Epoch 93/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.9522
# Epoch 94/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2745 - accuracy: 0.9565
# Epoch 95/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2996 - accuracy: 0.9609
# Epoch 96/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2986 - accuracy: 0.9391
# Epoch 97/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.9478
# Epoch 98/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9435
# Epoch 99/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3049 - accuracy: 0.9217
# Epoch 100/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2753 - accuracy: 0.9435
# Epoch 101/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2683 - accuracy: 0.9609
# Epoch 102/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3117 - accuracy: 0.9217
# Epoch 103/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2848 - accuracy: 0.9522
# Epoch 104/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2895 - accuracy: 0.9391
# Epoch 105/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2616 - accuracy: 0.9609
# Epoch 106/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2776 - accuracy: 0.9565
# Epoch 107/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.9522
# Epoch 108/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2835 - accuracy: 0.9478
# Epoch 109/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 0.9565
# Epoch 110/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2973 - accuracy: 0.9391
# Epoch 111/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2721 - accuracy: 0.9478
# Epoch 112/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2632 - accuracy: 0.9522
# Epoch 113/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2564 - accuracy: 0.9652
# Epoch 114/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2497 - accuracy: 0.9609
# Epoch 115/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.9348
# Epoch 116/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2722 - accuracy: 0.9565
# Epoch 117/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2679 - accuracy: 0.9652
# Epoch 118/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2739 - accuracy: 0.9522
# Epoch 119/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.9522
# Epoch 120/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2524 - accuracy: 0.9478
# Epoch 121/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2370 - accuracy: 0.9696
# Epoch 122/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2445 - accuracy: 0.9522
# Epoch 123/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2573 - accuracy: 0.9478
# Epoch 124/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.9435
# Epoch 125/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2640 - accuracy: 0.9565
# Epoch 126/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9435
# Epoch 127/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2399 - accuracy: 0.9652
# Epoch 128/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2783 - accuracy: 0.9304
# Epoch 129/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2684 - accuracy: 0.9391
# Epoch 130/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.9652
# Epoch 131/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2582 - accuracy: 0.9478
# Epoch 132/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2655 - accuracy: 0.9391
# Epoch 133/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.9652
# Epoch 134/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.9696
# Epoch 135/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2342 - accuracy: 0.9652
# Epoch 136/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.9565
# Epoch 137/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2389 - accuracy: 0.9565
# Epoch 138/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.9478
# Epoch 139/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2295 - accuracy: 0.9696
# Epoch 140/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.9478
# Epoch 141/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2273 - accuracy: 0.9652
# Epoch 142/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9652
# Epoch 143/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2598 - accuracy: 0.9348
# Epoch 144/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2338 - accuracy: 0.9652
# Epoch 145/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2351 - accuracy: 0.9565
# Epoch 146/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9522
# Epoch 147/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9739
# Epoch 148/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2501 - accuracy: 0.9478
# Epoch 149/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.9609
# Epoch 150/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9609
# Epoch 151/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2109 - accuracy: 0.9739
# Epoch 152/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2291 - accuracy: 0.9696
# Epoch 153/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2317 - accuracy: 0.9522
# Epoch 154/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2294 - accuracy: 0.9522
# Epoch 155/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9609
# Epoch 156/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.9609
# Epoch 157/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2367 - accuracy: 0.9565
# Epoch 158/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2144 - accuracy: 0.9696
# Epoch 159/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2540 - accuracy: 0.9609
# Epoch 160/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2320 - accuracy: 0.9522
# Epoch 161/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2356 - accuracy: 0.9652
# Epoch 162/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2301 - accuracy: 0.9478
# Epoch 163/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.9652
# Epoch 164/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9609
# Epoch 165/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2270 - accuracy: 0.9609
# Epoch 166/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2248 - accuracy: 0.9652
# Epoch 167/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2555 - accuracy: 0.9435
# Epoch 168/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2071 - accuracy: 0.9739
# Epoch 169/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2235 - accuracy: 0.9696
# Epoch 170/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 0.9652
# Epoch 171/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2276 - accuracy: 0.9696
# Epoch 172/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2043 - accuracy: 0.9696
# Epoch 173/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2171 - accuracy: 0.9652
# Epoch 174/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2332 - accuracy: 0.9565
# Epoch 175/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2392 - accuracy: 0.9478
# Epoch 176/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2264 - accuracy: 0.9522
# Epoch 177/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2172 - accuracy: 0.9652
# Epoch 178/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.9652
# Epoch 179/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2258 - accuracy: 0.9522
# Epoch 180/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2217 - accuracy: 0.9609
# Epoch 181/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2156 - accuracy: 0.9696
# Epoch 182/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1926 - accuracy: 0.9739
# Epoch 183/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2395 - accuracy: 0.9565
# Epoch 184/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2362 - accuracy: 0.9565
# Epoch 185/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9783
# Epoch 186/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2122 - accuracy: 0.9522
# Epoch 187/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2163 - accuracy: 0.9609
# Epoch 188/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2068 - accuracy: 0.9696
# Epoch 189/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2120 - accuracy: 0.9609
# Epoch 190/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.9522
# Epoch 191/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9652
# Epoch 192/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1993 - accuracy: 0.9739
# Epoch 193/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2027 - accuracy: 0.9696
# Epoch 194/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.9609
# Epoch 195/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1927 - accuracy: 0.9826
# Epoch 196/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.9652
# Epoch 197/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2187 - accuracy: 0.9783
# Epoch 198/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9522
# Epoch 199/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2065 - accuracy: 0.9522
# Epoch 200/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1922 - accuracy: 0.9783
# Epoch 201/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2105 - accuracy: 0.9652
# Epoch 202/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1848 - accuracy: 0.9783
# Epoch 203/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2074 - accuracy: 0.9522
# Epoch 204/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1832 - accuracy: 0.9870
# Epoch 205/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1965 - accuracy: 0.9696
# Epoch 206/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2052 - accuracy: 0.9696
# Epoch 207/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1853 - accuracy: 0.9696
# Epoch 208/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2027 - accuracy: 0.9565
# Epoch 209/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1891 - accuracy: 0.9783
# Epoch 210/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2050 - accuracy: 0.9478
# Epoch 211/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9478
# Epoch 212/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1915 - accuracy: 0.9696
# Epoch 213/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1866 - accuracy: 0.9870
# Epoch 214/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9522
# Epoch 215/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1828 - accuracy: 0.9783
# Epoch 216/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1892 - accuracy: 0.9826
# Epoch 217/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1882 - accuracy: 0.9783
# Epoch 218/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2121 - accuracy: 0.9478
# Epoch 219/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1916 - accuracy: 0.9783
# Epoch 220/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2020 - accuracy: 0.9652
# Epoch 221/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.9739
# Epoch 222/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1954 - accuracy: 0.9783
# Epoch 223/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9783
# Epoch 224/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1868 - accuracy: 0.9739
# Epoch 225/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9783
# Epoch 226/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9783
# Epoch 227/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1833 - accuracy: 0.9870
# Epoch 228/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9870
# Epoch 229/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1785 - accuracy: 0.9739
# Epoch 230/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.9696
# Epoch 231/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1694 - accuracy: 0.9826
# Epoch 232/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2063 - accuracy: 0.9652
# Epoch 233/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2030 - accuracy: 0.9522
# Epoch 234/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1817 - accuracy: 0.9870
# Epoch 235/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9696
# Epoch 236/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2001 - accuracy: 0.9739
# Epoch 237/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1940 - accuracy: 0.9739
# Epoch 238/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.9783
# Epoch 239/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1755 - accuracy: 0.9739
# Epoch 240/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9739
# Epoch 241/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.9652
# Epoch 242/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.9783
# Epoch 243/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1822 - accuracy: 0.9739
# Epoch 244/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1790 - accuracy: 0.9652
# Epoch 245/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2086 - accuracy: 0.9522
# Epoch 246/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1772 - accuracy: 0.9826
# Epoch 247/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9870
# Epoch 248/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1722 - accuracy: 0.9826
# Epoch 249/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1772 - accuracy: 0.9783
# Epoch 250/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1774 - accuracy: 0.9696
# Epoch 251/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1734 - accuracy: 0.9826
# Epoch 252/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1723 - accuracy: 0.9826
# Epoch 253/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1812 - accuracy: 0.9696
# Epoch 254/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1670 - accuracy: 0.9783
# Epoch 255/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1726 - accuracy: 0.9783
# Epoch 256/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1794 - accuracy: 0.9783
# Epoch 257/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1948 - accuracy: 0.9739
# Epoch 258/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1817 - accuracy: 0.9739
# Epoch 259/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1777 - accuracy: 0.9826
# Epoch 260/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1659 - accuracy: 0.9826
# Epoch 261/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1806 - accuracy: 0.9783
# Epoch 262/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1649 - accuracy: 0.9870
# Epoch 263/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1808 - accuracy: 0.9739
# Epoch 264/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.9739
# Epoch 265/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1708 - accuracy: 0.9783
# Epoch 266/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9913
# Epoch 267/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1627 - accuracy: 0.9913
# Epoch 268/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1753 - accuracy: 0.9783
# Epoch 269/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1582 - accuracy: 0.9870
# Epoch 270/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1665 - accuracy: 0.9826
# Epoch 271/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 0.9783
# Epoch 272/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1710 - accuracy: 0.9696
# Epoch 273/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1794 - accuracy: 0.9783
# Epoch 274/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1871 - accuracy: 0.9696
# Epoch 275/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1555 - accuracy: 0.9870
# Epoch 276/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9826
# Epoch 277/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1707 - accuracy: 0.9783
# Epoch 278/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1675 - accuracy: 0.9696
# Epoch 279/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1638 - accuracy: 0.9826
# Epoch 280/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9739
# Epoch 281/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1597 - accuracy: 0.9913
# Epoch 282/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1678 - accuracy: 0.9870
# Epoch 283/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1833 - accuracy: 0.9783
# Epoch 284/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1718 - accuracy: 0.9739
# Epoch 285/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1674 - accuracy: 0.9783
# Epoch 286/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2184 - accuracy: 0.9652
# Epoch 287/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.9652
# Epoch 288/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 0.9870
# Epoch 289/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1574 - accuracy: 0.9957
# Epoch 290/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1734 - accuracy: 0.9783
# Epoch 291/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1897 - accuracy: 0.9652
# Epoch 292/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1590 - accuracy: 0.9783
# Epoch 293/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1573 - accuracy: 0.9913
# Epoch 294/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1611 - accuracy: 0.9870
# Epoch 295/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1827 - accuracy: 0.9783
# Epoch 296/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1513 - accuracy: 0.9826
# Epoch 297/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1448 - accuracy: 0.9957
# Epoch 298/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.9696
# Epoch 299/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1577 - accuracy: 0.9913
# Epoch 300/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1500 - accuracy: 0.9913
# 2/2 [==============================] - 0s 2ms/step
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 22 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 22 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 22 dim * 2.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 22 dim * 2.5e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 22 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 22 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-06 (2.2e-16 eps * 22 dim * 2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 22 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 22 dim * 2.9e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 22 dim * 2.8e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 22 dim * 3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.6e-05 (2.2e-16 eps * 22 dim * 3.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-06 (2.2e-16 eps * 22 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-06 (2.2e-16 eps * 22 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-06 (2.2e-16 eps * 22 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-06 (2.2e-16 eps * 22 dim * 1.2e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.5e-06 (2.2e-16 eps * 22 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.5e-06 (2.2e-16 eps * 22 dim * 1.3e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7e-06 (2.2e-16 eps * 22 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7e-06 (2.2e-16 eps * 22 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-06 (2.2e-16 eps * 22 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-06 (2.2e-16 eps * 22 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-06 (2.2e-16 eps * 22 dim * 1.7e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 22 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-06 (2.2e-16 eps * 22 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.9e-06 (2.2e-16 eps * 22 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.2e-06 (2.2e-16 eps * 22 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-06 (2.2e-16 eps * 22 dim * 1.6e+09  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-07 (2.2e-16 eps * 22 dim * 1.7e+08  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-07 (2.2e-16 eps * 22 dim * 1.5e+08  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# Reducing data rank from 22 -> 22
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.6e-07 (2.2e-16 eps * 22 dim * 1.6e+08  max singular value)
#     Estimated rank (mag): 22
#     MAG: rank 22 computed from 22 data channels with 0 projectors
# ...
# Epoch 140/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.9522
# Epoch 141/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2976 - accuracy: 0.9478
# Epoch 142/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2606 - accuracy: 0.9478
# Epoch 143/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.9652
# Epoch 144/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2836 - accuracy: 0.9565
# Epoch 145/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2845 - accuracy: 0.9435
# Epoch 146/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.9522
# Epoch 147/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3034 - accuracy: 0.9304
# Epoch 148/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2972 - accuracy: 0.9261
# Epoch 149/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2800 - accuracy: 0.9391
# Epoch 150/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2908 - accuracy: 0.9348
# Epoch 151/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2596 - accuracy: 0.9609
# Epoch 152/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2759 - accuracy: 0.9522
# Epoch 153/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2757 - accuracy: 0.9522
# Epoch 154/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9522
# Epoch 155/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2684 - accuracy: 0.9522
# Epoch 156/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3273 - accuracy: 0.9261
# Epoch 157/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 0.9304
# Epoch 158/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2604 - accuracy: 0.9522
# Epoch 159/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2762 - accuracy: 0.9435
# Epoch 160/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2649 - accuracy: 0.9435
# Epoch 161/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2754 - accuracy: 0.9261
# Epoch 162/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2416 - accuracy: 0.9435
# Epoch 163/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 0.9522
# Epoch 164/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.9696
# Epoch 165/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.9478
# Epoch 166/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 0.9391
# Epoch 167/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2428 - accuracy: 0.9652
# Epoch 168/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2569 - accuracy: 0.9478
# Epoch 169/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2532 - accuracy: 0.9478
# Epoch 170/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2450 - accuracy: 0.9652
# Epoch 171/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2730 - accuracy: 0.9348
# Epoch 172/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2561 - accuracy: 0.9435
# Epoch 173/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2249 - accuracy: 0.9739
# Epoch 174/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.9522
# Epoch 175/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2656 - accuracy: 0.9522
# Epoch 176/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2432 - accuracy: 0.9522
# Epoch 177/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.9565
# Epoch 178/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2850 - accuracy: 0.9435
# Epoch 179/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2534 - accuracy: 0.9522
# Epoch 180/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2375 - accuracy: 0.9652
# Epoch 181/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2343 - accuracy: 0.9739
# Epoch 182/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2739 - accuracy: 0.9435
# Epoch 183/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2419 - accuracy: 0.9652
# Epoch 184/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2186 - accuracy: 0.9739
# Epoch 185/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2364 - accuracy: 0.9783
# Epoch 186/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2799 - accuracy: 0.9348
# Epoch 187/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2718 - accuracy: 0.9522
# Epoch 188/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2474 - accuracy: 0.9522
# Epoch 189/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2234 - accuracy: 0.9652
# Epoch 190/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9696
# Epoch 191/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2431 - accuracy: 0.9522
# Epoch 192/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2438 - accuracy: 0.9609
# Epoch 193/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2067 - accuracy: 0.9739
# Epoch 194/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2229 - accuracy: 0.9739
# Epoch 195/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.9652
# Epoch 196/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2405 - accuracy: 0.9652
# Epoch 197/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.9739
# Epoch 198/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.9609
# Epoch 199/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2306 - accuracy: 0.9652
# Epoch 200/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2391 - accuracy: 0.9609
# Epoch 201/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.9696
# Epoch 202/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2263 - accuracy: 0.9652
# Epoch 203/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2333 - accuracy: 0.9565
# Epoch 204/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2102 - accuracy: 0.9696
# Epoch 205/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9522
# Epoch 206/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2644 - accuracy: 0.9478
# Epoch 207/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.9696
# Epoch 208/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2072 - accuracy: 0.9783
# Epoch 209/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.9783
# Epoch 210/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.9826
# Epoch 211/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2287 - accuracy: 0.9609
# Epoch 212/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2280 - accuracy: 0.9609
# Epoch 213/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9696
# Epoch 214/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.9478
# Epoch 215/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2260 - accuracy: 0.9609
# Epoch 216/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2694 - accuracy: 0.9435
# Epoch 217/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2178 - accuracy: 0.9696
# Epoch 218/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2607 - accuracy: 0.9435
# Epoch 219/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9478
# Epoch 220/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2440 - accuracy: 0.9478
# Epoch 221/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.9696
# Epoch 222/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2138 - accuracy: 0.9696
# Epoch 223/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2107 - accuracy: 0.9739
# Epoch 224/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2308 - accuracy: 0.9696
# Epoch 225/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.9783
# Epoch 226/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2138 - accuracy: 0.9652
# Epoch 227/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9696
# Epoch 228/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.9565
# Epoch 229/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2157 - accuracy: 0.9739
# Epoch 230/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2037 - accuracy: 0.9870
# Epoch 231/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2092 - accuracy: 0.9652
# Epoch 232/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.9609
# Epoch 233/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2504 - accuracy: 0.9565
# Epoch 234/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9609
# Epoch 235/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1969 - accuracy: 0.9826
# Epoch 236/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2161 - accuracy: 0.9652
# Epoch 237/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2163 - accuracy: 0.9609
# Epoch 238/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2153 - accuracy: 0.9739
# Epoch 239/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1987 - accuracy: 0.9783
# Epoch 240/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2021 - accuracy: 0.9739
# Epoch 241/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2426 - accuracy: 0.9565
# Epoch 242/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2013 - accuracy: 0.9739
# Epoch 243/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2092 - accuracy: 0.9565
# Epoch 244/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2337 - accuracy: 0.9565
# Epoch 245/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1840 - accuracy: 0.9826
# Epoch 246/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.9739
# Epoch 247/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2501 - accuracy: 0.9435
# Epoch 248/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2039 - accuracy: 0.9783
# Epoch 249/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2075 - accuracy: 0.9739
# Epoch 250/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2275 - accuracy: 0.9565
# Epoch 251/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1743 - accuracy: 0.9826
# Epoch 252/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2226 - accuracy: 0.9522
# Epoch 253/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1804 - accuracy: 0.9826
# Epoch 254/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1887 - accuracy: 0.9783
# Epoch 255/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2426 - accuracy: 0.9522
# Epoch 256/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.9870
# Epoch 257/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2097 - accuracy: 0.9696
# Epoch 258/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2142 - accuracy: 0.9522
# Epoch 259/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.9913
# Epoch 260/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9739
# Epoch 261/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2331 - accuracy: 0.9565
# Epoch 262/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1799 - accuracy: 0.9870
# Epoch 263/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9652
# Epoch 264/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1817 - accuracy: 0.9826
# Epoch 265/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1714 - accuracy: 0.9913
# Epoch 266/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2044 - accuracy: 0.9696
# Epoch 267/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1899 - accuracy: 0.9739
# Epoch 268/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2004 - accuracy: 0.9739
# Epoch 269/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.9739
# Epoch 270/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2134 - accuracy: 0.9696
# Epoch 271/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2070 - accuracy: 0.9696
# Epoch 272/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.9783
# Epoch 273/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2078 - accuracy: 0.9609
# Epoch 274/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1900 - accuracy: 0.9783
# Epoch 275/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2008 - accuracy: 0.9652
# Epoch 276/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2161 - accuracy: 0.9652
# Epoch 277/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1787 - accuracy: 0.9913
# Epoch 278/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1866 - accuracy: 0.9783
# Epoch 279/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2043 - accuracy: 0.9739
# Epoch 280/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.9739
# Epoch 281/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1863 - accuracy: 0.9783
# Epoch 282/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1901 - accuracy: 0.9826
# Epoch 283/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1847 - accuracy: 0.9739
# Epoch 284/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2018 - accuracy: 0.9522
# Epoch 285/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2099 - accuracy: 0.9739
# Epoch 286/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1863 - accuracy: 0.9783
# Epoch 287/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1850 - accuracy: 0.9783
# Epoch 288/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1812 - accuracy: 0.9870
# Epoch 289/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.9739
# Epoch 290/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1923 - accuracy: 0.9739
# Epoch 291/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1906 - accuracy: 0.9652
# Epoch 292/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.9652
# Epoch 293/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1793 - accuracy: 0.9783
# Epoch 294/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1898 - accuracy: 0.9696
# Epoch 295/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9652
# Epoch 296/300
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.9739
# Epoch 297/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2100 - accuracy: 0.9652
# Epoch 298/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1679 - accuracy: 0.9826
# Epoch 299/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1682 - accuracy: 0.9783
# Epoch 300/300
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1791 - accuracy: 0.9870
# 2/2 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Metrics

# %%
import pandas as pd

scores = {'Accuracy':acc,'Kappa':ka,'Precision':prec,'Recall':recall}

Es = pd.DataFrame(scores)

avg = {'Accuracy':[np.mean(acc)],'Kappa':[np.mean(ka)],'Precision':[np.mean(prec)],'Recall':[np.mean(recall)]}

Avg = pd.DataFrame(avg)


T = pd.concat([Es,Avg])

T.index = ['F1','F2','F3','F4','F5','F6','F7','F8','F9','F10','Avg']
T.index.rename('Fold',inplace=True)

print(T)
# Out:
#       Accuracy     Kappa  Precision    Recall
# Fold
# F1    0.689655  0.587025   0.708298  0.689655
# F2    0.672414  0.558670   0.684445  0.672414
# F3    0.689655  0.587189   0.705879  0.689655
# F4    0.655172  0.539683   0.683986  0.655172
# F5    0.793103  0.724684   0.805430  0.793103
# F6    0.603448  0.462963   0.628135  0.603448
# F7    0.672414  0.557785   0.688659  0.672414
# F8    0.655172  0.534510   0.665572  0.655172
# F9    0.655172  0.527687   0.655723  0.655172
# F10   0.810345  0.743775   0.817501  0.810345
# Avg   0.689655  0.582397   0.704363  0.689655
