# %% [markdown]
# ## Dataset loading using braindecode

# %%
import braindecode
# Out:
# <frozen importlib._bootstrap>:219: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:219: FutureWarning: mne.io.pick.pick_channels_regexp is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:219: FutureWarning: mne.io.pick.channel_type is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\moabb\pipelines\__init__.py:26: ModuleNotFoundError: Tensorflow is not installed. You won't be able to use these MOABB pipelines if you attempt to do so.
#   warn(

# %%
import torch
from braindecode.models import EEGNetv4, EEGConformer, ATCNet, EEGITNet, EEGInception
from braindecode.datasets import MOABBDataset

# %%
raw_dataset = MOABBDataset(dataset_name="BNCI2014_001", subject_ids=None)

# %% [markdown]
# Preprocess dataset using braindecode API

# %%
from braindecode.preprocessing import create_windows_from_events
from braindecode.preprocessing import exponential_moving_standardize, preprocess, Preprocessor

# %%
# low_freq = 4
# high_freq = 38
# resample_freq = 250

# # preprocess data using "braindecode.preprocessor"
# # only use eeg(stim channels must be removed)
# preprocessors = [Preprocessor('pick', picks=['eeg'])]

# # if pick_channels:
# #     preprocessors.append(Preprocessor('pick', picks=pick_channels))
# # preprocessors.append(Preprocessor(lambda data: multiply(data, 1e6)))


# # if low_freq or high_freq:
#     # preprocessors.append(Preprocessor('filter', l_freq=low_freq, h_freq=high_freq))
# if resample_freq:
#     preprocessors.append(Preprocessor('resample', sfreq=resample_freq))
# preprocessors.append(Preprocessor(exponential_moving_standardize, factor_new=1e-3))
# preprocess(raw_dataset, preprocessors)

# from braindecode.preprocessing import MNEPreproc, NumpyPreproc, preprocess

low_cut_hz = 4.  # low cut frequency for filtering
high_cut_hz = 38.  # high cut frequency for filtering
# Parameters for exponential moving standardization
factor_new = 1e-3
init_block_size = 1000

preprocessors = [
    # keep only EEG sensors
    Preprocessor(fn='pick_types', eeg=True, meg=False, stim=False),
    # convert from volt to microvolt, directly modifying the numpy array
    Preprocessor(fn=lambda x: x * 1e6),
    # bandpass filter
    Preprocessor(fn='filter', l_freq=low_cut_hz, h_freq=high_cut_hz),
    # exponential moving standardization
    Preprocessor(fn=exponential_moving_standardize, factor_new=factor_new,
        init_block_size=init_block_size)
]

# Preprocess the data
preprocess(raw_dataset, preprocessors)
# Out:
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\preprocessing\preprocess.py:55: UserWarning: Preprocessing choices with lambda functions cannot be saved.
#   warn('Preprocessing choices with lambda functions cannot be saved.')
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# ...
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s

# %% [markdown]
# Window Split (for each trail start and end)

# %%
start_offset = -0.5
stop_offset = 0

sfreq = raw_dataset.datasets[0].raw.info['sfreq']
#assert all([ds.raw.info['sfreq'] == sfreq for ds in raw_dataset.datasets])
trial_start_offset_samples = int(start_offset * sfreq)
trial_stop_offset_samples = int(stop_offset * sfreq)

windows_dataset = create_windows_from_events(
    raw_dataset,
    trial_start_offset_samples,
    trial_stop_offset_samples,
    preload=True,
)
# Out:
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']

# %%
import pandas as pd
meta = pd.DataFrame(windows_dataset.get_metadata())
meta.to_csv('windows_dataset.csv')
meta
# Out:
#     i_window_in_trial  i_start_in_trial  i_stop_in_trial  target  subject  \
# 0                   0               125             1250       3        1
# 1                   0              2128             3253       0        1
# 2                   0              4046             5171       2        1
# 3                   0              5998             7123       1        1
# 4                   0              8006             9131       1        1
# ..                ...               ...              ...     ...      ...
# 43                  0             86625            87750       0        9
# 44                  0             88531            89656       3        9
# 45                  0             90459            91584       0        9
# 46                  0             92573            93698       1        9
# 47                  0             94632            95757       0        9
#
#    session run
# 0   0train   0
# 1   0train   0
# 2   0train   0
# 3   0train   0
# 4   0train   0
# ..     ...  ..
# 43   1test   5
# 44   1test   5
# 45   1test   5
# 46   1test   5
# 47   1test   5
#
# [5184 rows x 7 columns]

# %%
sess_list = meta['session'].tolist()

# %%
import numpy as np

# %%
np.unique(meta['session'], return_counts = True)
# Out:
# (array(['0train', '1test'], dtype=object), array([2592, 2592], dtype=int64))

# %% [markdown]
# Get additional dataset details and set model configuration

# %%
n_channels = raw_dataset[0][0].shape[0]
n_times = windows_dataset[0][0].shape[1]
n_classes = 4 # number of classes in the dataset used

n_epochs = 100
lr = 0.001
batch_size = 64

# variables to save the model
save = 'store_true'
save_dir = 'models/'
strategy = 'within-subject' # 'within-subject' or 'cross-subject'
model_name = 'EEGNet' # 'EEGNet', 'EEGConformer', 'ATCNet', 'EEGITNet', 'EEGInception'
verbose = 2

# %% [markdown]
# Split data  into test and train based on window subset

# %%
from skorch.helper import SliceDataset
from skorch.callbacks import LRScheduler, TrainEndCheckpoint
from skorch import NeuralNetClassifier

cuda = torch.cuda.is_available()

# %%
str(sess_list[0])
# Out:
# '0train'

# %%
X_train = []
y_train = []
X_test = []
y_test = []
for i in range(len(windows_dataset)):
    x, target, window_ind = windows_dataset[i]
    # print(f"Shape of window {i}: {x.shape}, Label: {target}")
    if sess_list[i]=='0train':
        X_train.append(x)
        y_train.append(target)
    else:
        if i<3456:
            X_train.append(x)
            y_train.append(target)
        else:
            X_test.append(x)
            y_test.append(target)

# %%
# X = []
# y = []
# for i in range(len(windows_dataset)):
#     x, target, window_ind = windows_dataset[i]
#     # print(f"Shape of window {i}: {x.shape}, Label: {target}")
#     X.append(x)
#     y.append(target)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
enc = OneHotEncoder()
y_train = enc.fit_transform(np.array(y_train).reshape(-1,1)).toarray()
y_test = enc.transform(np.array(y_test).reshape(-1,1)).toarray()

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=16)

# %%
print("Train class split:")
unique_elements, counts = np.unique(np.argmax(y_train, axis=1), return_counts=True)
for value, count in zip(unique_elements, counts):
    print(f"{value}: {count}")
print("Test class split:")
unique_elements, counts = np.unique(np.argmax(y_test, axis=1), return_counts=True)
for value, count in zip(unique_elements, counts):
    print(f"{value}: {count}")
# Out:
# Train class split:
# 0: 1080
# 1: 1080
# 2: 1080
# 3: 1080
# Test class split:
# 0: 216
# 1: 216
# 2: 216
# 3: 216

# %%
X_train.shape
# Out:
# (4320, 22, 1125)

# %%
np.unique(np.argmax(y_test, axis=1),return_counts=True)
# Out:
# (array([0, 1, 2, 3], dtype=int64), array([216, 216, 216, 216], dtype=int64))

# %%
np.unique(np.argmax(y_train, axis=1),return_counts=True)
# Out:
# (array([0, 1, 2, 3], dtype=int64),
#  array([1080, 1080, 1080, 1080], dtype=int64))

# %%
from sklearn.metrics import *

# %%
def test_metrics(model, X_test = X_test):
    pred = model.predict(X_test)
    # print(np.argmax(y_test, axis=1)[0])
    # print(pred[0])
    print("Accuracy: ", accuracy_score(np.argmax(y_test, axis=1), pred))
    print("Precision: ", precision_score(np.argmax(y_test, axis=1), pred, average='weighted'))
    print("Recall: ", recall_score(np.argmax(y_test, axis=1), pred, average='weighted'))
    print("F1: ", f1_score(np.argmax(y_test, axis=1), pred, average='weighted'))

# %%
def test_metrics_onehot(model, X_test = X_test):
    pred = model.predict(X_test)
    i=0
    for a in pred:
        temp = [0, 0, 0, 0] 
        temp[np.argmax(a)] = 1
        pred[i] = temp
        i+=1
    # print(y_test[0])
    # print(pred[0])
    print("Accuracy: ", accuracy_score(y_test, pred))
    print("Precision: ", precision_score(y_test, pred, average='weighted'))
    print("Recall: ", recall_score(y_test, pred, average='weighted'))
    print("F1: ", f1_score(y_test, pred, average='weighted'))

# %% [markdown]
# ### Noise

# %%
import numpy as np
import os
import mne
from scipy.io import loadmat

def add_awgn_noise(signal, snr):
    """
    Add AWGN noise to the signal based on a desired SNR.
    Args:
        signal (numpy.array): Original EEG signals.
        snr (float): Desired signal-to-noise ratio in dB.
    Returns:
        numpy.array: Signal with added Gaussian noise.
    """
    sig_power = np.mean(np.power(signal, 2))
    sig_db = 10 * np.log10(sig_power)
    noise_db = sig_db - snr
    noise_power = np.power(10, noise_db / 10)
    noise = np.random.normal(0, np.sqrt(noise_power), signal.shape)
    noisy_signal = signal + noise
    return noisy_signal
def create_noisy_dataset(data, snr):
    """
    Apply AWGN to each sample in the dataset.
    Args:
        data (numpy.array): Original EEG dataset.
        snr (float): Desired signal-to-noise ratio.
    Returns:
        numpy.array: Noisy EEG dataset.
    """
    noisy_data = np.array([add_awgn_noise(sample, snr) for sample in data])
    return noisy_data

from numpy import dot
from numpy.linalg import norm

def cosine_similarity(arr1, arr2):
    return dot(arr1.flatten(), arr2.flatten()) / (norm(arr1) * norm(arr2))

# %%
X_test_noise = create_noisy_dataset(X_test, snr = 8)
similarity = cosine_similarity(X_test_noise, X_test)
print("Similarity with original data: ",similarity)
# Out:
# Similarity with original data:  0.9292072554756868

# %%
X_test_noise_2 = create_noisy_dataset(X_test, snr = 12)
similarity = cosine_similarity(X_test_noise_2, X_test)
print("Similarity with original data: ",similarity)
# Out:
# Similarity with original data:  0.9700179191880101

# %%
from sklearn.metrics import *
from sklearn.model_selection import ShuffleSplit
import matplotlib.pyplot as plt

# %%
cv = ShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 16)

# %% [markdown]
# ### Train

# %%
def CV_train(model, X, X_test, cnn = False, convlstm = False, batch_size = 32, n_epochs = 50, y_out = y_train, y_out_test = y_test):
    acc = []
    f1 = []
    prec = []
    recall = []
    results = {}
    best_model = model
    prev_metric = 0
    best_hist = []
    for train_idx, val_idx in cv.split(y_out):

        nn = [] 

        label_train, _ = y_out[train_idx], y_out[val_idx]
        y_train, y_val = y_out[train_idx], y_out[val_idx] 

        X_train = X[train_idx] 
        X_val = X[val_idx] 
        
        if cnn:
            X_train = np.expand_dims(X_train,-1)
        elif convlstm:
            X_train = np.expand_dims(np.expand_dims(X_train, -1),-1)

        nn = model

        history = nn.fit(X_train, y_train, validation_data = (X_val, y_val), batch_size = batch_size, epochs = n_epochs)

        y_pred = nn.predict(X_val)
        pred = (y_pred == y_pred.max(axis=1)[:,None]).astype(int)

        acc_score = accuracy_score(y_val.argmax(axis=1), pred.argmax(axis=1))
        acc.append(acc_score)
        f1_val = (f1_score(y_val.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
        f1.append(f1_val)
        prec.append(precision_score(y_val.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
        recall.append(recall_score(y_val.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
        if f1_val > prev_metric: 
            prev_metric = f1_val
            best_model = model
            best_hist = history
    
    test_pred = best_model.predict(X_test)
    pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
    acc.append(accuracy_score(y_out_test.argmax(axis=1), pred.argmax(axis=1)))
    f1.append(f1_score(y_out_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
    prec.append(precision_score(y_out_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
    recall.append(recall_score(y_out_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
    
    results['Accuracy'] = acc
    results['F1'] = f1
    results['Precision'] = prec
    results['Recall'] = recall

    plt.plot(best_hist.history['loss'], label='Training Loss')
    plt.plot(best_hist.history['val_loss'], label='Validation Loss', color = 'b')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()
    plt.plot(best_hist.history['accuracy'], label='Training Accuracy')
    plt.plot(best_hist.history['val_accuracy'], label='Validation Accuracy', color = 'b')
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    return best_model, results

# %%
import mne 
import numpy as np
import pandas as pd
import torch
import os
import braindecode
import matplotlib.pyplot as plt
from braindecode.models import EEGNetv4, EEGConformer, ATCNet, EEGITNet, EEGInception
from braindecode.datasets import MOABBDataset
from braindecode.preprocessing import create_windows_from_events
from braindecode.preprocessing import exponential_moving_standardize, preprocess, Preprocessor

import scipy.io
import pywt
from mne.decoding import CSP # Common Spatial Pattern Filtering
from sklearn.preprocessing import OneHotEncoder
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten, Reshape, ConvLSTM1D, Conv2D
from keras import regularizers
from sklearn import preprocessing
from sklearn.metrics import *
from sklearn.model_selection import ShuffleSplit

# %%
from braindecode.augmentation import AugmentedDataLoader, SignFlip
from braindecode.augmentation import FrequencyShift

freq_shift = FrequencyShift(
    probability=.5,
    sfreq=sfreq,
    max_delta_freq=2.  # the frequency shifts are sampled now between -2 and 2 Hz
)

sign_flip = SignFlip(probability=.1)

transforms = [
    freq_shift,
    sign_flip
]

# %%
def build_mlp_classifier(num_layers = 1, lr = 0.01):
    classifier = Sequential()
    classifier.add(Flatten())
    #First Layer
    classifier.add(Dense(units = 256, kernel_initializer = 'uniform', activation = 'relu', 
                         kernel_regularizer=regularizers.l2(0.01))) # L2 regularization
    classifier.add(Dropout(0.4))
    # Intermediate Layers
    for itr in range(num_layers):
        classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu', 
                             kernel_regularizer=regularizers.l2(0.01))) # L2 regularization
        classifier.add(Dropout(0.4))   
    # Last Layer
    classifier.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'softmax'))
    classifier.compile(optimizer = keras.optimizers.Adam(lr=lr) , loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
mlp = build_mlp_classifier(4, 0.0001)
mlp, mlp_results = CV_train(mlp, X_train, X_test, n_epochs=100)

# %%
mlp_results
# Out:
# {'Accuracy': [0.2713498622589532, 0.230719794344473],
#  'F1': [0.11583081877576115, 0.08650486284038204],
#  'Precision': [0.07363074774795286, 0.05323162350235592],
#  'Recall': [0.2713498622589532, 0.230719794344473]}

# %%
test_metrics_onehot(mlp, X_test_noise)
# Out:
# 49/49 [==============================] - 0s 5ms/step
# [0. 0. 0. 1.]
# [0. 1. 0. 0.]
# Accuracy:  0.230719794344473
# Precision:  0.05323162350235592
# Recall:  0.230719794344473
# F1:  0.08650486284038204
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mlp.save('models/mlp_raw.h5')

# %%
mlp = keras.models.load_model('models/mlp_raw.h5')

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

# %%
def build_eegnet_classifier(nb_classes=4, Chans = 22, Samples = 1125, 
             dropoutRate = 0.3, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    classifier = Model(inputs=input1, outputs=softmax)
    classifier.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    return classifier

# %%
X_train.shape
# Out:
# (4320, 22, 1125)

# %%
eegnet = build_eegnet_classifier()
eegnet, eegnet_results = CV_train(eegnet, np.expand_dims(X_train,-1), np.expand_dims(X_test,-1), n_epochs=100)
# Out:
# Epoch 1/100
# 108/108 [==============================] - 18s 161ms/step - loss: 1.3709 - accuracy: 0.2931 - val_loss: 1.3813 - val_accuracy: 0.2546
# Epoch 2/100
# 108/108 [==============================] - 16s 149ms/step - loss: 1.2977 - accuracy: 0.3950 - val_loss: 1.3488 - val_accuracy: 0.3229
# Epoch 3/100
# 108/108 [==============================] - 15s 143ms/step - loss: 1.2499 - accuracy: 0.4196 - val_loss: 1.2821 - val_accuracy: 0.4155
# Epoch 4/100
# 108/108 [==============================] - 16s 149ms/step - loss: 1.2254 - accuracy: 0.4369 - val_loss: 1.2332 - val_accuracy: 0.4225
# Epoch 5/100
# 108/108 [==============================] - 17s 159ms/step - loss: 1.1943 - accuracy: 0.4656 - val_loss: 1.2003 - val_accuracy: 0.4572
# Epoch 6/100
# 108/108 [==============================] - 16s 148ms/step - loss: 1.1670 - accuracy: 0.4644 - val_loss: 1.1550 - val_accuracy: 0.4803
# Epoch 7/100
# 108/108 [==============================] - 16s 150ms/step - loss: 1.1565 - accuracy: 0.4850 - val_loss: 1.1447 - val_accuracy: 0.4699
# Epoch 8/100
# 108/108 [==============================] - 16s 150ms/step - loss: 1.1494 - accuracy: 0.4864 - val_loss: 1.1324 - val_accuracy: 0.4873
# Epoch 9/100
# 108/108 [==============================] - 16s 144ms/step - loss: 1.1422 - accuracy: 0.4954 - val_loss: 1.1350 - val_accuracy: 0.4826
# Epoch 10/100
# 108/108 [==============================] - 16s 144ms/step - loss: 1.1313 - accuracy: 0.5017 - val_loss: 1.1311 - val_accuracy: 0.4988
# Epoch 11/100
# 108/108 [==============================] - 16s 144ms/step - loss: 1.1248 - accuracy: 0.5116 - val_loss: 1.1267 - val_accuracy: 0.4873
# Epoch 12/100
# 108/108 [==============================] - 16s 146ms/step - loss: 1.1182 - accuracy: 0.5124 - val_loss: 1.1086 - val_accuracy: 0.5035
# Epoch 13/100
# 108/108 [==============================] - 16s 145ms/step - loss: 1.1088 - accuracy: 0.5101 - val_loss: 1.1168 - val_accuracy: 0.5035
# Epoch 14/100
# 108/108 [==============================] - 16s 149ms/step - loss: 1.0982 - accuracy: 0.5284 - val_loss: 1.1160 - val_accuracy: 0.4919
# Epoch 15/100
# 108/108 [==============================] - 16s 151ms/step - loss: 1.1022 - accuracy: 0.5272 - val_loss: 1.1022 - val_accuracy: 0.5185
# Epoch 16/100
# 108/108 [==============================] - 16s 151ms/step - loss: 1.0992 - accuracy: 0.5263 - val_loss: 1.0793 - val_accuracy: 0.5359
# Epoch 17/100
# 108/108 [==============================] - 16s 146ms/step - loss: 1.0842 - accuracy: 0.5336 - val_loss: 1.0891 - val_accuracy: 0.5174
# Epoch 18/100
# 108/108 [==============================] - 16s 145ms/step - loss: 1.0808 - accuracy: 0.5333 - val_loss: 1.0795 - val_accuracy: 0.5231
# Epoch 19/100
# 108/108 [==============================] - 16s 148ms/step - loss: 1.0749 - accuracy: 0.5344 - val_loss: 1.0735 - val_accuracy: 0.5116
# Epoch 20/100
# 108/108 [==============================] - 16s 145ms/step - loss: 1.0759 - accuracy: 0.5396 - val_loss: 1.0839 - val_accuracy: 0.5370
# Epoch 21/100
# 108/108 [==============================] - 16s 147ms/step - loss: 1.0687 - accuracy: 0.5454 - val_loss: 1.1072 - val_accuracy: 0.5093
# Epoch 22/100
# 108/108 [==============================] - 16s 145ms/step - loss: 1.0683 - accuracy: 0.5466 - val_loss: 1.0650 - val_accuracy: 0.5475
# Epoch 23/100
# 108/108 [==============================] - 16s 147ms/step - loss: 1.0527 - accuracy: 0.5538 - val_loss: 1.0701 - val_accuracy: 0.5301
# Epoch 24/100
# 108/108 [==============================] - 16s 144ms/step - loss: 1.0542 - accuracy: 0.5538 - val_loss: 1.0466 - val_accuracy: 0.5451
# Epoch 25/100
# 108/108 [==============================] - 16s 149ms/step - loss: 1.0432 - accuracy: 0.5616 - val_loss: 1.0491 - val_accuracy: 0.5347
# Epoch 26/100
# 108/108 [==============================] - 16s 147ms/step - loss: 1.0399 - accuracy: 0.5634 - val_loss: 1.0216 - val_accuracy: 0.5741
# Epoch 27/100
# 108/108 [==============================] - 16s 149ms/step - loss: 1.0380 - accuracy: 0.5668 - val_loss: 1.0627 - val_accuracy: 0.5185
# Epoch 28/100
# 108/108 [==============================] - 16s 146ms/step - loss: 1.0393 - accuracy: 0.5564 - val_loss: 1.0449 - val_accuracy: 0.5637
# Epoch 29/100
# 108/108 [==============================] - 16s 148ms/step - loss: 1.0360 - accuracy: 0.5668 - val_loss: 1.0347 - val_accuracy: 0.5428
# Epoch 30/100
# 108/108 [==============================] - 16s 147ms/step - loss: 1.0354 - accuracy: 0.5720 - val_loss: 1.0481 - val_accuracy: 0.5475
# Epoch 31/100
# 108/108 [==============================] - 16s 148ms/step - loss: 1.0247 - accuracy: 0.5700 - val_loss: 1.0368 - val_accuracy: 0.5671
# Epoch 32/100
# 108/108 [==============================] - 16s 146ms/step - loss: 1.0282 - accuracy: 0.5613 - val_loss: 1.0331 - val_accuracy: 0.5671
# Epoch 33/100
# 108/108 [==============================] - 16s 147ms/step - loss: 1.0178 - accuracy: 0.5720 - val_loss: 1.0380 - val_accuracy: 0.5532
# Epoch 34/100
# 108/108 [==============================] - 16s 153ms/step - loss: 1.0212 - accuracy: 0.5692 - val_loss: 1.0490 - val_accuracy: 0.5370
# Epoch 35/100
# 108/108 [==============================] - 17s 155ms/step - loss: 1.0210 - accuracy: 0.5775 - val_loss: 1.0273 - val_accuracy: 0.5579
# Epoch 36/100
# 108/108 [==============================] - 17s 154ms/step - loss: 1.0140 - accuracy: 0.5787 - val_loss: 1.0719 - val_accuracy: 0.5255
# Epoch 37/100
100
# 108/108 [==============================] - 16s 149ms/step - loss: 0.9426 - accuracy: 0.6123 - val_loss: 0.9818 - val_accuracy: 0.5880
# Epoch 81/100
# 108/108 [==============================] - 16s 148ms/step - loss: 0.9462 - accuracy: 0.6094 - val_loss: 0.9474 - val_accuracy: 0.6181
# Epoch 82/100
# 108/108 [==============================] - 16s 150ms/step - loss: 0.9437 - accuracy: 0.6117 - val_loss: 0.9552 - val_accuracy: 0.6030
# Epoch 83/100
# 108/108 [==============================] - 16s 151ms/step - loss: 0.9403 - accuracy: 0.6111 - val_loss: 0.9459 - val_accuracy: 0.6065
# Epoch 84/100
# 108/108 [==============================] - 16s 149ms/step - loss: 0.9319 - accuracy: 0.6169 - val_loss: 0.9337 - val_accuracy: 0.6285
# Epoch 85/100
# 108/108 [==============================] - 16s 149ms/step - loss: 0.9243 - accuracy: 0.6169 - val_loss: 0.9560 - val_accuracy: 0.6065
# Epoch 86/100
# 108/108 [==============================] - 16s 146ms/step - loss: 0.9200 - accuracy: 0.6215 - val_loss: 0.9539 - val_accuracy: 0.6088
# Epoch 87/100
# 108/108 [==============================] - 16s 153ms/step - loss: 0.9289 - accuracy: 0.6105 - val_loss: 0.9351 - val_accuracy: 0.6007
# Epoch 88/100
# 108/108 [==============================] - 16s 151ms/step - loss: 0.9251 - accuracy: 0.6209 - val_loss: 0.9800 - val_accuracy: 0.5995
# Epoch 89/100
# 108/108 [==============================] - 16s 149ms/step - loss: 0.9343 - accuracy: 0.6134 - val_loss: 0.9854 - val_accuracy: 0.5671
# Epoch 90/100
# 108/108 [==============================] - 16s 149ms/step - loss: 0.9352 - accuracy: 0.6039 - val_loss: 0.9762 - val_accuracy: 0.5718
# Epoch 91/100
# 108/108 [==============================] - 16s 151ms/step - loss: 0.9244 - accuracy: 0.6241 - val_loss: 0.9648 - val_accuracy: 0.5799
# Epoch 92/100
# 108/108 [==============================] - 16s 147ms/step - loss: 0.9190 - accuracy: 0.6181 - val_loss: 0.9553 - val_accuracy: 0.5891
# Epoch 93/100
# 108/108 [==============================] - 16s 149ms/step - loss: 0.9166 - accuracy: 0.6253 - val_loss: 0.9541 - val_accuracy: 0.5961
# Epoch 94/100
# 108/108 [==============================] - 16s 147ms/step - loss: 0.9216 - accuracy: 0.6262 - val_loss: 0.9328 - val_accuracy: 0.6285
# Epoch 95/100
# 108/108 [==============================] - 18s 169ms/step - loss: 0.9263 - accuracy: 0.6218 - val_loss: 0.9259 - val_accuracy: 0.6065
# Epoch 96/100
# 108/108 [==============================] - 18s 170ms/step - loss: 0.9232 - accuracy: 0.6244 - val_loss: 0.9328 - val_accuracy: 0.6181
# Epoch 97/100
# 108/108 [==============================] - 18s 168ms/step - loss: 0.9235 - accuracy: 0.6221 - val_loss: 0.9648 - val_accuracy: 0.5972
# Epoch 98/100
# 108/108 [==============================] - 17s 158ms/step - loss: 0.9161 - accuracy: 0.6189 - val_loss: 0.9314 - val_accuracy: 0.6157
# Epoch 99/100
# 108/108 [==============================] - 17s 156ms/step - loss: 0.9161 - accuracy: 0.6149 - val_loss: 0.9333 - val_accuracy: 0.6343
# Epoch 100/100
# 108/108 [==============================] - 17s 160ms/step - loss: 0.9228 - accuracy: 0.6204 - val_loss: 0.9804 - val_accuracy: 0.5845
# 27/27 [==============================] - 1s 21ms/step
# 27/27 [==============================] - 1s 21ms/step

# %%
eegnet_results
# Out:
# {'Accuracy': [0.5844907407407407, 0.6516203703703703],
#  'F1': [0.5656868363028261, 0.6439276067910379],
#  'Precision': [0.6236449032847725, 0.6793830855201862],
#  'Recall': [0.5844907407407407, 0.6516203703703703]}

# %%
test_pred = eegnet.predict(X_test_noise_2)
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 15
# Out:
# 27/27 [==============================] - 1s 18ms/step
# Accuracy:  0.6157407407407407
# F1:  0.6131609384190305
# Precision:  0.6396812167864149
# Recall:  0.6157407407407407

# %%
test_pred = eegnet.predict(X_test_noise)
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 8
# Out:
# 27/27 [==============================] - 1s 18ms/step
# Accuracy:  0.5254629629629629
# F1:  0.48767349456385695
# Precision:  0.5851267475488261
# Recall:  0.5254629629629629

# %%
eegnet.save('models/eegnet.h5')

# %%
eegnet = keras.models.load_model('models/eegnet.h5')

# %%
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))

# %%
def build_shallow_conv_net(nb_classes=4, Chans = 22, Samples = 1125, dropoutRate = 0.5):
    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                        input_shape=(Chans, Samples, 1),
                        kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    return Model(inputs=input_main, outputs=softmax)

# %%
scn = build_shallow_conv_net()
scn.compile(optimizer=keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
scn, scn_results = CV_train(scn, np.expand_dims(X_train,-1), np.expand_dims(X_test,-1), n_epochs=100)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 108/108 [==============================] - 17s 151ms/step - loss: 1.5054 - accuracy: 0.3212 - val_loss: 1.4052 - val_accuracy: 0.3507
# Epoch 2/100
# 108/108 [==============================] - 15s 143ms/step - loss: 1.3566 - accuracy: 0.3929 - val_loss: 1.3273 - val_accuracy: 0.4086
# Epoch 3/100
# 108/108 [==============================] - 14s 134ms/step - loss: 1.2828 - accuracy: 0.4366 - val_loss: 1.4827 - val_accuracy: 0.3495
# Epoch 4/100
# 108/108 [==============================] - 15s 138ms/step - loss: 1.2435 - accuracy: 0.4523 - val_loss: 1.2639 - val_accuracy: 0.4236
# Epoch 5/100
# 108/108 [==============================] - 15s 141ms/step - loss: 1.2103 - accuracy: 0.4777 - val_loss: 1.2438 - val_accuracy: 0.4456
# Epoch 6/100
# 108/108 [==============================] - 15s 143ms/step - loss: 1.1869 - accuracy: 0.4789 - val_loss: 1.3020 - val_accuracy: 0.4479
# Epoch 7/100
# 108/108 [==============================] - 15s 138ms/step - loss: 1.1520 - accuracy: 0.5012 - val_loss: 1.2496 - val_accuracy: 0.4398
# Epoch 8/100
# 108/108 [==============================] - 15s 143ms/step - loss: 1.1419 - accuracy: 0.5055 - val_loss: 1.2608 - val_accuracy: 0.4468
# Epoch 9/100
# 108/108 [==============================] - 16s 146ms/step - loss: 1.1170 - accuracy: 0.5284 - val_loss: 1.2398 - val_accuracy: 0.4502
# Epoch 10/100
# 108/108 [==============================] - 15s 141ms/step - loss: 1.1056 - accuracy: 0.5229 - val_loss: 1.2093 - val_accuracy: 0.4757
# Epoch 11/100
100
# 108/108 [==============================] - 15s 137ms/step - loss: 0.9248 - accuracy: 0.6209 - val_loss: 1.1221 - val_accuracy: 0.5093
# Epoch 35/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.9425 - accuracy: 0.6001 - val_loss: 1.0565 - val_accuracy: 0.5451
# Epoch 36/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9438 - accuracy: 0.6137 - val_loss: 1.0727 - val_accuracy: 0.5208
# Epoch 37/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.9193 - accuracy: 0.6120 - val_loss: 1.1943 - val_accuracy: 0.4977
# Epoch 38/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.9376 - accuracy: 0.6215 - val_loss: 1.0755 - val_accuracy: 0.5347
# Epoch 39/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.9169 - accuracy: 0.6276 - val_loss: 1.1028 - val_accuracy: 0.5197
# Epoch 40/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.9197 - accuracy: 0.6143 - val_loss: 1.0741 - val_accuracy: 0.5324
# Epoch 41/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.9121 - accuracy: 0.6259 - val_loss: 1.0656 - val_accuracy: 0.5405
# Epoch 42/100
# 108/108 [==============================] - 15s 136ms/step - loss: 0.9044 - accuracy: 0.6354 - val_loss: 1.0754 - val_accuracy: 0.5394
# Epoch 43/100
# 108/108 [==============================] - 15s 137ms/step - loss: 0.8994 - accuracy: 0.6311 - val_loss: 1.1438 - val_accuracy: 0.5104
# Epoch 44/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.9168 - accuracy: 0.6340 - val_loss: 1.0438 - val_accuracy: 0.5729
# Epoch 45/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.9134 - accuracy: 0.6325 - val_loss: 1.0839 - val_accuracy: 0.5336
# Epoch 46/100
# 108/108 [==============================] - 15s 136ms/step - loss: 0.8994 - accuracy: 0.6424 - val_loss: 1.0648 - val_accuracy: 0.5428
# Epoch 47/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.8865 - accuracy: 0.6369 - val_loss: 1.0732 - val_accuracy: 0.5382
# Epoch 48/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.9164 - accuracy: 0.6331 - val_loss: 1.0712 - val_accuracy: 0.5359
# Epoch 49/100
# 108/108 [==============================] - 15s 139ms/step - loss: 0.8867 - accuracy: 0.6412 - val_loss: 1.0471 - val_accuracy: 0.5509
# Epoch 50/100
# 108/108 [==============================] - 15s 138ms/step - loss: 0.8929 - accuracy: 0.6438 - val_loss: 1.0788 - val_accuracy: 0.5069
# Epoch 51/100
# 108/108 [==============================] - 15s 139ms/step - loss: 0.9027 - accuracy: 0.6351 - val_loss: 1.0632 - val_accuracy: 0.5451
# Epoch 52/100
# 108/108 [==============================] - 15s 136ms/step - loss: 0.8755 - accuracy: 0.6536 - val_loss: 1.0102 - val_accuracy: 0.5625
# Epoch 53/100
# 108/108 [==============================] - 15s 140ms/step - loss: 0.8611 - accuracy: 0.6675 - val_loss: 1.0285 - val_accuracy: 0.5764
# Epoch 54/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.8656 - accuracy: 0.6658 - val_loss: 1.0057 - val_accuracy: 0.5556
# Epoch 55/100
# 108/108 [==============================] - 15s 139ms/step - loss: 0.8767 - accuracy: 0.6447 - val_loss: 1.0914 - val_accuracy: 0.5231
# Epoch 56/100
# 108/108 [==============================] - 15s 136ms/step - loss: 0.9130 - accuracy: 0.6354 - val_loss: 1.0438 - val_accuracy: 0.5625
# Epoch 57/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.8754 - accuracy: 0.6455 - val_loss: 1.0434 - val_accuracy: 0.5602
# Epoch 58/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.8620 - accuracy: 0.6510 - val_loss: 1.0357 - val_accuracy: 0.5475
# Epoch 59/100
# 108/108 [==============================] - 15s 136ms/step - loss: 0.8592 - accuracy: 0.6580 - val_loss: 1.0470 - val_accuracy: 0.5579
# Epoch 60/100
# 108/108 [==============================] - 15s 137ms/step - loss: 0.8684 - accuracy: 0.6499 - val_loss: 1.0031 - val_accuracy: 0.5775
# Epoch 61/100
# 108/108 [==============================] - 15s 134ms/step - loss: 0.8743 - accuracy: 0.6496 - val_loss: 1.1028 - val_accuracy: 0.5324
# Epoch 62/100
# 108/108 [==============================] - 15s 135ms/step - loss: 0.
100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8145 - accuracy: 0.6889 - val_loss: 0.9938 - val_accuracy: 0.5810
# Epoch 87/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8209 - accuracy: 0.6881 - val_loss: 1.0502 - val_accuracy: 0.5498
# Epoch 88/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8378 - accuracy: 0.6707 - val_loss: 1.0246 - val_accuracy: 0.5752
# Epoch 89/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8274 - accuracy: 0.6811 - val_loss: 1.0014 - val_accuracy: 0.5880
# Epoch 90/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8058 - accuracy: 0.6898 - val_loss: 1.0441 - val_accuracy: 0.5637
# Epoch 91/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.8209 - accuracy: 0.6823 - val_loss: 0.9770 - val_accuracy: 0.5972
# Epoch 92/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.8196 - accuracy: 0.6852 - val_loss: 0.9703 - val_accuracy: 0.5856
# Epoch 93/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.8279 - accuracy: 0.6803 - val_loss: 1.0257 - val_accuracy: 0.5671
# Epoch 94/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8294 - accuracy: 0.6730 - val_loss: 0.9887 - val_accuracy: 0.5683
# Epoch 95/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8184 - accuracy: 0.6861 - val_loss: 1.0118 - val_accuracy: 0.5706
# Epoch 96/100
# 108/108 [==============================] - 15s 138ms/step - loss: 0.8355 - accuracy: 0.6667 - val_loss: 0.9751 - val_accuracy: 0.5938
# Epoch 97/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8327 - accuracy: 0.6736 - val_loss: 0.9705 - val_accuracy: 0.5891
# Epoch 98/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.8186 - accuracy: 0.6829 - val_loss: 1.1131 - val_accuracy: 0.5359
# Epoch 99/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.8084 - accuracy: 0.6933 - val_loss: 0.9661 - val_accuracy: 0.6053
# Epoch 100/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.8153 - accuracy: 0.6872 - val_loss: 1.0238 - val_accuracy: 0.5683
# 27/27 [==============================] - 1s 30ms/step
# 27/27 [==============================] - 1s 30ms/step

# %%
scn_results
# Out:
# {'Accuracy': [0.5682870370370371, 0.6145833333333334],
#  'F1': [0.5645457612614778, 0.616098089154518],
#  'Precision': [0.5814075294623892, 0.6290582541203776],
#  'Recall': [0.5682870370370371, 0.6145833333333334]}

# %%
test_pred = scn.predict(np.expand_dims(X_test_noise_2,-1))
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 15
# Out:
# 27/27 [==============================] - 1s 31ms/step
# Accuracy:  0.5636574074074074
# F1:  0.5622026586567475
# Precision:  0.6264537979386517
# Recall:  0.5636574074074074

# %%
test_pred = scn.predict(np.expand_dims(X_test_noise,-1))
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 8
# Out:
# 27/27 [==============================] - 1s 33ms/step
# Accuracy:  0.42592592592592593
# F1:  0.38483418947818854
# Precision:  0.6550406880383184
# Recall:  0.42592592592592593

# %%
scn.save('models/scn.h5')

# %%
scn = keras.models.load_model('models/scn.h5', custom_objects={'square':square, 'log':log})

# %%
def build_deep_conv_net(nb_classes=4, Chans = 22, Samples = 1125, dropoutRate = 0.5):
    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)
  
    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)
    
    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)
    
    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)
    
    flatten      = Flatten()(block4)
    
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %%
dcn = build_deep_conv_net()
dcn.compile(optimizer=keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
dcn, dcn_results = CV_train(dcn, np.expand_dims(X_train,-1), np.expand_dims(X_test,-1), n_epochs=100)
# Out:
# Epoch 1/100
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 108/108 [==============================] - 16s 135ms/step - loss: 1.7101 - accuracy: 0.2674 - val_loss: 1.4290 - val_accuracy: 0.2674
# Epoch 2/100
# 108/108 [==============================] - 14s 132ms/step - loss: 1.6226 - accuracy: 0.3128 - val_loss: 1.6824 - val_accuracy: 0.2581
# Epoch 3/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.6078 - accuracy: 0.3229 - val_loss: 2.0796 - val_accuracy: 0.2593
# Epoch 4/100
# 108/108 [==============================] - 14s 132ms/step - loss: 1.5285 - accuracy: 0.3264 - val_loss: 2.3370 - val_accuracy: 0.2477
# Epoch 5/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.4526 - accuracy: 0.3469 - val_loss: 1.8725 - val_accuracy: 0.2639
# Epoch 6/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.4221 - accuracy: 0.3657 - val_loss: 2.1352 - val_accuracy: 0.2569
# Epoch 7/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.3766 - accuracy: 0.3799 - val_loss: 1.5885 - val_accuracy: 0.3171
# Epoch 8/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.3356 - accuracy: 0.4013 - val_loss: 1.5051 - val_accuracy: 0.3171
# Epoch 9/100
# 108/108 [==============================] - 14s 132ms/step - loss: 1.2857 - accuracy: 0.4317 - val_loss: 1.2745 - val_accuracy: 0.4167
# Epoch 10/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.2456 - accuracy: 0.4427 - val_loss: 1.4722 - val_accuracy: 0.3322
# Epoch 11/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.2114 - accuracy: 0.4601 - val_loss: 1.1691 - val_accuracy: 0.4803
# Epoch 12/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.1971 - accuracy: 0.4630 - val_loss: 1.2444 - val_accuracy: 0.4514
# Epoch 13/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.1626 - accuracy: 0.4841 - val_loss: 1.1968 - val_accuracy: 0.4653
# Epoch 14/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.1465 - accuracy: 0.4884 - val_loss: 1.1775 - val_accuracy: 0.4861
# Epoch 15/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.1253 - accuracy: 0.5130 - val_loss: 1.2477 - val_accuracy: 0.4352
# Epoch 16/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.1309 - accuracy: 0.5012 - val_loss: 1.2676 - val_accuracy: 0.4456
# Epoch 17/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.1264 - accuracy: 0.5266 - val_loss: 1.1934 - val_accuracy: 0.4595
# Epoch 18/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.1051 - accuracy: 0.5214 - val_loss: 1.3006 - val_accuracy: 0.4387
# Epoch 19/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.0962 - accuracy: 0.5174 - val_loss: 1.1153 - val_accuracy: 0.5255
# Epoch 20/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.0659 - accuracy: 0.5370 - val_loss: 1.1482 - val_accuracy: 0.4931
# Epoch 21/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.0735 - accuracy: 0.5480 - val_loss: 1.2285 - val_accuracy: 0.4896
# Epoch 22/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.0618 - accuracy: 0.5420 - val_loss: 1.0903 - val_accuracy: 0.5243
# Epoch 23/100
# 108/108 [==============================] - 14s 129ms/step - loss: 1.0476 - accuracy: 0.5477 - val_loss: 1.1721 - val_accuracy: 0.4942
# Epoch 24/100
# 108/108 [==============================] - 14s 131ms/step - loss: 1.0508 - accuracy: 0.5584 - val_loss: 1.1344 - val_accuracy: 0.5046
# Epoch 25/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.0344 - accuracy: 0.5683 - val_loss: 1.0675 - val_accuracy: 0.5602
# Epoch 26/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.0431 - accuracy: 0.5605 - val_loss: 1.0764 - val_accuracy: 0.5486
# Epoch 27/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.0382 - accuracy: 0.5651 - val_loss: 1.0585 - val_accuracy: 0.5347
# Epoch 28/100
# 108/108 [==============================] - 14s 129ms/step - loss: 1.0327 - accuracy: 0.5602 - val_loss: 1.0714 - val_accuracy: 0.5278
# Epoch 29/100
# 108/108 [==============================] - 14s 128ms/step - loss: 1.0217 - accuracy: 0.5639 - val_loss: 1.0614 - val_accuracy: 0.5428
# Epoch 30/100
# 108/108 [==============================] - 14s 129ms/step - loss: 1.0355 - accuracy: 0.5564 - val_loss: 1.0648 - val_accuracy: 0.5706
# Epoch 31/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9959 - accuracy: 0.5868 - val_loss: 1.0438 - val_accuracy: 0.5613
# Epoch 32/100
# 108/108 [==============================] - 14s 129ms/step - loss: 1.0100 - accuracy: 0.5677 - val_loss: 1.1081 - val_accuracy: 0.5301
# Epoch 33/100
# 108/108 [==============================] - 14s 129ms/step - loss: 1.0159 - accuracy: 0.5657 - val_loss: 1.0747 - val_accuracy: 0.5521
# Epoch 34/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.0010 - accuracy: 0.5787 - val_loss: 1.0126 - val_accuracy: 0.5683
# Epoch 35/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9857 - accuracy: 0.5874 - val_loss: 1.0482 - val_accuracy: 0.5579
# Epoch 36/100
# 108/108 [==============================] - 14s 130ms/step - loss: 1.0061 - accuracy: 0.5825 - val_loss: 1.0281 - val_accuracy: 0.5718
# Epoch 37/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9962 - accuracy: 0.5799 - val_loss: 1.1059 - val_accuracy: 0.5278
# Epoch 38/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9981 - accuracy: 0.5859 - val_loss: 1.0604 - val_accuracy: 0.5613
# Epoch 39/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9769 - accuracy: 0.5894 - val_loss: 1.0003 - val_accuracy: 0.5637
# Epoch 40/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9858 - accuracy: 0.5906 - val_loss: 1.0657 - val_accuracy: 0.5498
# Epoch 41/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9730 - accuracy: 0.5926 - val_loss: 1.0065 - val_accuracy: 0.5764
# Epoch 42/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9816 - accuracy: 0.5883 - val_loss: 1.0638 - val_accuracy: 0.5532
# Epoch 43/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9820 - accuracy: 0.5926 - val_loss: 1.0502 - val_accuracy: 0.5579
# Epoch 44/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9714 - accuracy: 0.5888 - val_loss: 1.0081 - val_accuracy: 0.5579
# Epoch 45/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9851 - accuracy: 0.5807 - val_loss: 1.0344 - val_accuracy: 0.5579
# Epoch 46/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9653 - accuracy: 0.6071 - val_loss: 1.0462 - val_accuracy: 0.5556
# Epoch 47/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9821 - accuracy: 0.5848 - val_loss: 1.0055 - val_accuracy: 0.5694
# Epoch 48/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9698 - accuracy: 0.5958 - val_loss: 1.0093 - val_accuracy: 0.5718
# Epoch 49/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9485 - accuracy: 0.6091 - val_loss: 0.9955 - val_accuracy: 0.5880
# Epoch 50/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9745 - accuracy: 0.5992 - val_loss: 1.0288 - val_accuracy: 0.5637
# Epoch 51/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9555 - accuracy: 0.5969 - val_loss: 1.0211 - val_accuracy: 0.5671
# Epoch 52/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9632 - accuracy: 0.5923 - val_loss: 1.0460 - val_accuracy: 0.5637
# Epoch 53/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9720 - accuracy: 0.5865 - val_loss: 0.9778 - val_accuracy: 0.5845
# Epoch 54/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9646 - accuracy: 0.5998 - val_loss: 1.0577 - val_accuracy: 0.5324
# Epoch 55/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9497 - accuracy: 0.6102 - val_loss: 0.9954 - val_accuracy: 0.5822
# Epoch 56/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9553 - accuracy: 0.6042 - val_loss: 0.9736 - val_accuracy: 0.6157
# Epoch 57/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.9232 - accuracy: 0.6204 - val_loss: 0.9884 - val_accuracy: 0.5718
# Epoch 58/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9580 - accuracy: 0.6021 - val_loss: 0.9860 - val_accuracy: 0.5799
# Epoch 59/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9537 - accuracy: 0.6071 - val_loss: 0.9729 - val_accuracy: 0.5845
# Epoch 60/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.9323 - accuracy: 0.6137 - val_loss: 0.9624 - val_accuracy: 0.5810
# Epoch 61/100
# 108/108 [==============================] - 15s 134ms/step - loss: 0.9273 - accuracy: 0.6062 - val_loss: 1.0266 - val_accuracy: 0.5683
# Epoch 62/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9449 - accuracy: 0.6079 - val_loss: 0.9887 - val_accuracy: 0.5938
# Epoch 63/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9500 - accuracy: 0.6042 - val_loss: 0.9794 - val_accuracy: 0.5845
# Epoch 64/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.9313 - accuracy: 0.6224 - val_loss: 0.9599 - val_accuracy: 0.5868
# Epoch 65/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9310 - accuracy: 0.6183 - val_loss: 0.9894 - val_accuracy: 0.5903
# Epoch 66/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9283 - accuracy: 0.6212 - val_loss: 1.0606 - val_accuracy: 0.5243
# Epoch 67/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9265 - accuracy: 0.6146 - val_loss: 0.9990 - val_accuracy: 0.5579
# Epoch 68/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9406 - accuracy: 0.6042 - val_loss: 1.0042 - val_accuracy: 0.5694
# Epoch 69/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9372 - accuracy: 0.6108 - val_loss: 1.0004 - val_accuracy: 0.5752
# Epoch 70/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9183 - accuracy: 0.6218 - val_loss: 0.9779 - val_accuracy: 0.5903
# Epoch 71/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9483 - accuracy: 0.5987 - val_loss: 1.0280 - val_accuracy: 0.5625
# Epoch 72/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.9218 - accuracy: 0.6244 - val_loss: 0.9849 - val_accuracy: 0.5845
# Epoch 73/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9163 - accuracy: 0.6259 - val_loss: 1.0002 - val_accuracy: 0.5648
# Epoch 74/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9146 - accuracy: 0.6238 - val_loss: 0.9743 - val_accuracy: 0.5914
# Epoch 75/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9148 - accuracy: 0.6227 - val_loss: 0.9685 - val_accuracy: 0.5938
# Epoch 76/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9187 - accuracy: 0.6195 - val_loss: 1.0179 - val_accuracy: 0.5833
# Epoch 77/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9077 - accuracy: 0.6276 - val_loss: 0.9986 - val_accuracy: 0.5775
# Epoch 78/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9096 - accuracy: 0.6233 - val_loss: 1.0026 - val_accuracy: 0.5648
# Epoch 79/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9060 - accuracy: 0.6302 - val_loss: 1.0228 - val_accuracy: 0.5683
# Epoch 80/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9094 - accuracy: 0.6215 - val_loss: 1.0139 - val_accuracy: 0.5544
# Epoch 81/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9175 - accuracy: 0.6181 - val_loss: 0.9847 - val_accuracy: 0.5775
# Epoch 82/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9143 - accuracy: 0.6264 - val_loss: 0.9798 - val_accuracy: 0.5868
# Epoch 83/100
# 108/108 [==============================] - 14s 134ms/step - loss: 0.9037 - accuracy: 0.6296 - val_loss: 0.9373 - val_accuracy: 0.5856
# Epoch 84/100
# 108/108 [==============================] - 14s 133ms/step - loss: 0.9033 - accuracy: 0.6264 - val_loss: 0.9251 - val_accuracy: 0.6146
# Epoch 85/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9058 - accuracy: 0.6357 - val_loss: 0.9492 - val_accuracy: 0.5868
# Epoch 86/100
# 108/108 [==============================] - 14s 130ms/step - loss: 0.8972 - accuracy: 0.6288 - val_loss: 0.9616 - val_accuracy: 0.5995
# Epoch 87/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9147 - accuracy: 0.6137 - val_loss: 0.9702 - val_accuracy: 0.5891
# Epoch 88/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.8907 - accuracy: 0.6343 - val_loss: 0.9793 - val_accuracy: 0.5891
# Epoch 89/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9110 - accuracy: 0.6308 - val_loss: 0.9519 - val_accuracy: 0.5949
# Epoch 90/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8841 - accuracy: 0.6386 - val_loss: 0.9954 - val_accuracy: 0.5775
# Epoch 91/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9131 - accuracy: 0.6241 - val_loss: 0.9357 - val_accuracy: 0.5810
# Epoch 92/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8981 - accuracy: 0.6267 - val_loss: 0.9775 - val_accuracy: 0.5972
# Epoch 93/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8858 - accuracy: 0.6412 - val_loss: 0.9428 - val_accuracy: 0.6076
# Epoch 94/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.9051 - accuracy: 0.6276 - val_loss: 0.9757 - val_accuracy: 0.5810
# Epoch 95/100
# 108/108 [==============================] - 14s 132ms/step - loss: 0.8849 - accuracy: 0.6369 - val_loss: 0.9595 - val_accuracy: 0.5972
# Epoch 96/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8907 - accuracy: 0.6406 - val_loss: 0.9369 - val_accuracy: 0.6065
# Epoch 97/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8757 - accuracy: 0.6438 - val_loss: 0.9822 - val_accuracy: 0.5775
# Epoch 98/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8772 - accuracy: 0.6389 - val_loss: 0.9350 - val_accuracy: 0.6019
# Epoch 99/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.9108 - accuracy: 0.6201 - val_loss: 0.9658 - val_accuracy: 0.6100
# Epoch 100/100
# 108/108 [==============================] - 14s 131ms/step - loss: 0.8927 - accuracy: 0.6293 - val_loss: 0.9369 - val_accuracy: 0.6030
# 27/27 [==============================] - 1s 35ms/step
# 27/27 [==============================] - 1s 36ms/step

# %%
dcn_results
# Out:
# {'Accuracy': [0.6030092592592593, 0.6099537037037037],
#  'F1': [0.5917885140072242, 0.5893488503579134],
#  'Precision': [0.6067420271467648, 0.6183133726738377],
#  'Recall': [0.6030092592592593, 0.6099537037037037]}

# %%
test_pred = dcn.predict(np.expand_dims(X_test_noise_2,-1))
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 15
# Out:
# 27/27 [==============================] - 1s 36ms/step
# Accuracy:  0.5891203703703703
# F1:  0.5777006594328525
# Precision:  0.6003727520351626
# Recall:  0.5891203703703703

# %%
test_pred = dcn.predict(np.expand_dims(X_test_noise,-1))
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 8
# Out:
# 27/27 [==============================] - 1s 38ms/step
# Accuracy:  0.5590277777777778
# F1:  0.547928522428475
# Precision:  0.5876595148909717
# Recall:  0.5590277777777778

# %%
dcn.save('models/dcn.h5')

# %%
dcn = keras.models.load_model('models/dcn.h5')

# %%
n_epochs=100
from skorch.callbacks import LRScheduler
callbacks = [("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1)),]
eegv4 = NeuralNetClassifier(module=EEGNetv4,
        iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
        iterator_train__transforms=transforms, 
        module__n_chans=22,
        module__n_outputs=4,
        module__n_times=1125,
        module__kernel_length=32,
        module__drop_prob=0.5,
        criterion=torch.nn.CrossEntropyLoss,
        optimizer=torch.optim.Adam,
        optimizer__lr=0.0001,
        train_split=None,
        iterator_train__shuffle=True,
        batch_size=32,
        callbacks=callbacks,
        device='cuda' if cuda else 'cpu',
        verbose=verbose
        )

eegv4.fit(X_train, y_train, epochs=n_epochs)
# Out:
#   epoch    train_loss      lr     dur
# -------  ------------  ------  ------
#       1        1.4830  0.0001  4.6786
#       2        1.4593  0.0001  4.5594
#       3        1.4499  0.0001  4.7155
#       4        1.4410  0.0001  4.6791
#       5        1.4261  0.0001  4.5022
#       6        1.4273  0.0001  4.6792
#       7        1.4229  0.0001  4.7143
#       8        1.4113  0.0001  4.7697
#       9        1.4139  0.0001  4.4788
#      10        1.4042  0.0001  4.6060
#      11        1.4116  0.0001  4.6367
#      12        1.3979  0.0001  4.9939
#      13        1.3972  0.0001  4.6058
#      14        1.3960  0.0001  4.5292
#      15        1.3946  0.0001  4.4683
#      16        1.3827  0.0001  4.4772
#      17        1.3807  0.0001  4.3775
#      18        1.3780  0.0001  4.4462
#      19        1.3768  0.0001  4.3890
#      20        1.3710  0.0001  4.5213
#      21        1.3694  0.0001  4.5680
#      22        1.3466  0.0001  4.3128
#      23        1.3480  0.0001  4.5412
#      24        1.3537  0.0001  4.5373
#      25        1.3501  0.0001  4.5212
#      26        1.3372  0.0001  4.5459
#      27        1.3324  0.0001  4.5577
#      28        1.3241  0.0001  4.4802
#      29        1.3275  0.0001  4.5029
#      30        1.3198  0.0001  4.4176
#      31        1.3183  0.0001  4.6281
#      32        1.3184  0.0001  4.5791
#      33        1.3156  0.0001  4.3556
#      34        1.3188  0.0001  4.4073
#      35        1.3060  0.0001  4.6502
#      36        1.3073  0.0001  4.4821
#      37        1.3002  0.0001  4.4250
#      38        1.3007  0.0001  4.5940
#      39        1.3018  0.0001  4.6632
#      40        1.2962  0.0001  4.5003
#      41        1.2953  0.0001  4.5079
#      42        1.3012  0.0001  4.6199
#      43        1.3034  0.0001  4.6275
#      44        1.2926  0.0001  4.7120
#      45        1.2928  0.0001  4.7053
#      46        1.2906  0.0001  4.6971
#      47        1.2919  0.0001  4.6053
#      48        1.2907  0.0001  4.7838
#      49        1.2812  0.0001  4.4794
#      50        1.2850  0.0001  4.4654
#      51        1.2850  0.0000  4.4853
#      52        1.2881  0.0000  4.7298
#      53        1.2743  0.0000  4.4254
#      54        1.2811  0.0000  4.6921
#      55        1.2830  0.0000  4.5927
#      56        1.2769  0.0000  4.6372
#      57        1.2831  0.0000  4.5449
#      58        1.2800  0.0000  4.5892
#      59        1.2833  0.0000  4.3661
#      60        1.2715  0.0000  4.3958
#      61        1.2682  0.0000  4.4427
#      62        1.2655  0.0000  4.3876
#      63        1.2683  0.0000  4.4276
#      64        1.2681  0.0000  4.6183
#      65        1.2762  0.0000  4.5620
#      66        1.2635  0.0000  4.9038
#      67        1.2683  0.0000  4.6851
#      68        1.2691  0.0000  4.5911
#      69        1.2760  0.0000  4.3932
#      70        1.2692  0.0000  4.5041
#      71        1.2704  0.0000  4.5529
#      72        1.2716  0.0000  4.4683
#      73        1.2697  0.0000  4.4184
#      74        1.2680  0.0000  4.6519
#      75        1.2592  0.0000  4.7386
#      76        1.2653  0.0000  4.8847
#      77        1.2714  0.0000  4.5191
#      78        1.2683  0.0000  4.3118
#      79        1.2603  0.0000  4.1752
#      80        1.2619  0.0000  4.7028
#      81        1.2625  0.0000  5.1699
#      82        1.2688  0.0000  4.7878
#      83        1.2645  0.0000  4.5373
#      84        1.2613  0.0000  4.5955
#      85        1.2600  0.0000  4.6116
#      86        1.2646  0.0000  4.5199
#      87        1.2659  0.0000  4.7069
#      88        1.2625  0.0000  4.5332
#      89        1.2578  0.0000  4.4473
#      90        1.2626  0.0000  4.4821
#      91        1.2603  0.0000  4.4852
#      92        1.2586  0.0000  4.4920
#      93        1.2568  0.0000  4.6729
#      94        1.2580  0.0000  4.6043
#      95        1.2638  0.0000  4.7716
#      96        1.2671  0.0000  4.7016
#      97        1.2659  0.0000  4.6029
#      98        1.2689  0.0000  4.6867
#      99        1.2609  0.0000  4.6077
#     100        1.2677  0.0000  4.6590
# <class 'skorch.classifier.NeuralNetClassifier'>[initialized](
#   module_=======================================================================================================================================================
#   Layer (type (var_name):depth-idx)                  Input Shape               Output Shape              Param #                   Kernel Shape
#   ======================================================================================================================================================
#   EEGNetv4 (EEGNetv4)                                [1, 22, 1125]             [1, 4]                    --                        --
#   ├─Ensure4d (ensuredims): 1-1                       [1, 22, 1125]             [1, 22, 1125, 1]          --                        --
#   ├─Rearrange (dimshuffle): 1-2                      [1, 22, 1125, 1]          [1, 1, 22, 1125]          --                        --
#   ├─Conv2d (conv_temporal): 1-3                      [1, 1, 22, 1125]          [1, 8, 22, 1126]          256                       [1, 32]
#   ├─BatchNorm2d (bnorm_temporal): 1-4                [1, 8, 22, 1126]          [1, 8, 22, 1126]          16                        --
#   ├─Conv2dWithConstraint (conv_spatial): 1-5         [1, 8, 22, 1126]          [1, 16, 1, 1126]          352                       [22, 1]
#   ├─BatchNorm2d (bnorm_1): 1-6                       [1, 16, 1, 1126]          [1, 16, 1, 1126]          32                        --
#   ├─Expression (elu_1): 1-7                          [1, 16, 1, 1126]          [1, 16, 1, 1126]          --                        --
#   ├─AvgPool2d (pool_1): 1-8                          [1, 16, 1, 1126]          [1, 16, 1, 281]           --                        [1, 4]
#   ├─Dropout (drop_1): 1-9                            [1, 16, 1, 281]           [1, 16, 1, 281]           --                        --
#   ├─Conv2d (conv_separable_depth): 1-10              [1, 16, 1, 281]           [1, 16, 1, 282]           256                       [1, 16]
#   ├─Conv2d (conv_separable_point): 1-11              [1, 16, 1, 282]           [1, 16, 1, 282]           256                       [1, 1]
#   ├─BatchNorm2d (bnorm_2): 1-12                      [1, 16, 1, 282]           [1, 16, 1, 282]           32                        --
#   ├─Expression (elu_2): 1-13                         [1, 16, 1, 282]           [1, 16, 1, 282]           --                        --
#   ├─AvgPool2d (pool_2): 1-14                         [1, 16, 1, 282]           [1, 16, 1, 35]            --                        [1, 8]
#   ├─Dropout (drop_2): 1-15                           [1, 16, 1, 35]            [1, 16, 1, 35]            --                        --
#   ├─Sequential (final_layer): 1-16                   [1, 16, 1, 35]            [1, 4]                    --                        --
#   │    └─Conv2d (conv_classifier): 2-1               [1, 16, 1, 35]            [1, 4, 1, 1]              2,244                     [1, 35]
#   │    └─Rearrange (permute_back): 2-2               [1, 4, 1, 1]              [1, 4, 1, 1]              --                        --
#   │    └─Expression (squeeze): 2-3                   [1, 4, 1, 1]              [1, 4]                    --                        --
#   ======================================================================================================================================================
#   Total params: 3,444
#   Trainable params: 3,444
#   Non-trainable params: 0
#   Total mult-adds (M): 6.88
#   ======================================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 3.57
#   Params size (MB): 0.01
#   Estimated Total Size (MB): 3.68
#   ======================================================================================================================================================,
# )

# %%
test_metrics(eegv4)
# Out:
# Accuracy:  0.44328703703703703
# Precision:  0.430394299156055
# Recall:  0.44328703703703703
# F1:  0.4254131958213223

# %%
print("Train Accuracy: ", eegv4.score(X_train, np.argmax(y_train, axis=1)))
print("Test Accuracy: ", eegv4.score(X_test, np.argmax(y_test, axis=1)))

train_loss = eegv4.history[:, 'train_loss']
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train Accuracy:  0.47129629629629627
# Test Accuracy:  0.44328703703703703

# %%
from braindecode.models import *

# %%
callbacks = [("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1))]
atcnet = NeuralNetClassifier(module=ATCNet,
        iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
        iterator_train__transforms=transforms, 
        module__n_chans=22,
        module__n_outputs=4,
        module__n_times=1125,
        module__add_log_softmax=False,
        # module__kernel_length=32,
        # module__drop_prob=0.5,
        criterion=torch.nn.CrossEntropyLoss,
        optimizer=torch.optim.Adam,
        optimizer__lr=0.0001,
        train_split=None,
        iterator_train__shuffle=True,
        batch_size=32,
        callbacks=callbacks,
        device='cuda' if cuda else 'cpu',
        verbose=verbose
        )
# clf.callbacks.append(TrainEndCheckpoint(dirname=save_dir + f'\\S{subject}'))
atcnet.fit(X_train, y_train, epochs=100)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\Convolution.cpp:1041.)
#   return F.conv2d(input, weight, bias, self.stride,
#   epoch    train_loss      lr     dur
# -------  ------------  ------  ------
#       1        1.4495  0.0001  9.6868
#       2        1.4244  0.0001  9.7729
#       3        1.4148  0.0001  9.7094
#       4        1.4074  0.0001  9.6191
#       5        1.4070  0.0001  9.6998
#       6        1.3882  0.0001  9.7742
#       7        1.3834  0.0001  9.6371
#       8        1.3629  0.0001  9.7655
#       9        1.3537  0.0001  9.7490
#      10        1.3435  0.0001  9.7327
#      11        1.3353  0.0001  9.6934
#      12        1.3355  0.0001  9.6708
#      13        1.3169  0.0001  9.8105
#      14        1.3140  0.0001  9.7087
#      15        1.3079  0.0001  9.7956
#      16        1.3074  0.0001  9.6804
#      17        1.3012  0.0001  9.6752
#      18        1.2938  0.0001  9.7072
# <class 'skorch.classifier.NeuralNetClassifier'>[initialized](
#   module_============================================================================================================================================================
#   Layer (type (var_name):depth-idx)                       Input Shape               Output Shape              Param #                   Kernel Shape
#   ===========================================================================================================================================================
#   ATCNet (ATCNet)                                         [1, 22, 1125]             [1, 4]                    --                        --
#   ├─Ensure4d (ensuredims): 1-1                            [1, 22, 1125]             [1, 22, 1125, 1]          --                        --
#   ├─Rearrange (dimshuffle): 1-2                           [1, 22, 1125, 1]          [1, 1, 1125, 22]          --                        --
#   ├─_ConvBlock (conv_block): 1-3                          [1, 1, 1125, 22]          [1, 32, 20, 1]            --                        --
#   │    └─Conv2d (conv1): 2-1                              [1, 1, 1125, 22]          [1, 16, 1125, 22]         1,024                     [64, 1]
#   │    └─BatchNorm2d (bn1): 2-2                           [1, 16, 1125, 22]         [1, 16, 1125, 22]         32                        --
#   │    └─Conv2d (conv2): 2-3                              [1, 16, 1125, 22]         [1, 32, 1125, 1]          704                       [1, 22]
#   │    └─BatchNorm2d (bn2): 2-4                           [1, 32, 1125, 1]          [1, 32, 1125, 1]          64                        --
#   │    └─ELU (activation2): 2-5                           [1, 32, 1125, 1]          [1, 32, 1125, 1]          --                        --
#   │    └─AvgPool2d (pool2): 2-6                           [1, 32, 1125, 1]          [1, 32, 140, 1]           --                        [8, 1]
#   │    └─Dropout2d (drop2): 2-7                           [1, 32, 140, 1]           [1, 32, 140, 1]           --                        --
#   │    └─Conv2d (conv3): 2-8                              [1, 32, 140, 1]           [1, 32, 140, 1]           16,384                    [16, 1]
#   │    └─BatchNorm2d (bn3): 2-9                           [1, 32, 140, 1]           [1, 32, 140, 1]           64                        --
#   │    └─ELU (activation3): 2-10                          [1, 32, 140, 1]           [1, 32, 140, 1]           --                        --
#   │    └─AvgPool2d (pool3): 2-11                          [1, 32, 140, 1]           [1, 32, 20, 1]            --                        [7, 1]
#   │    └─Dropout2d (drop3): 2-12                          [1, 32, 20, 1]            [1, 32, 20, 1]            --                        --
#   ├─ModuleList (attention_blocks): 1-16                   --                        --                        (recursive)               --
#   │    └─_AttentionBlock (0): 2-13                        [1, 32, 16]               [1, 32, 16]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-1                 [1, 32, 16]               [1, 16, 32]               --                        --
#   │    │    └─LayerNorm (ln): 3-2                         [1, 16, 32]               [1, 16, 32]               64                        --
#   │    │    └─_MHA (mha): 3-3                             [1, 16, 32]               [1, 16, 32]               2,128                     --
#   │    │    └─Dropout (drop): 3-4                         [1, 16, 32]               [1, 16, 32]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-5                 [1, 16, 32]               [1, 32, 16]               --                        --
#   ├─ModuleList (temporal_conv_nets): 1-17                 --                        --                        (recursive)               --
#   │    └─Sequential (0): 2-14                             [1, 32, 16]               [1, 32, 16]               8,384                     --
#   │    │    └─_TCNResidualBlock (0): 3-6                  [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (0): 2-24                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-10                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (0): 2-24                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-10                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (0): 2-24                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-12                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (0): 2-24                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-16                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (0): 2-24                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-16                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   ├─ModuleList (final_layer): 1-18                        --                        --                        (recursive)               --
#   │    └─MaxNormLinear (0): 2-26                          [1, 32]                   [1, 4]                    132                       --
#   ├─ModuleList (attention_blocks): 1-16                   --                        --                        (recursive)               --
#   │    └─_AttentionBlock (1): 2-27                        [1, 32, 16]               [1, 32, 16]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-18                [1, 32, 16]               [1, 16, 32]               --                        --
#   │    │    └─LayerNorm (ln): 3-19                        [1, 16, 32]               [1, 16, 32]               64                        --
#   │    │    └─_MHA (mha): 3-20                            [1, 16, 32]               [1, 16, 32]               2,128                     --
#   │    │    └─Dropout (drop): 3-21                        [1, 16, 32]               [1, 16, 32]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-22                [1, 16, 32]               [1, 32, 16]               --                        --
#   ├─ModuleList (temporal_conv_nets): 1-17                 --                        --                        (recursive)               --
#   │    └─Sequential (1): 2-28                             [1, 32, 16]               [1, 32, 16]               8,384                     --
#   │    │    └─_TCNResidualBlock (0): 3-23                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (1): 2-38                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-27                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (1): 2-38                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-27                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (1): 2-38                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-29                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (1): 2-38                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-33                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (1): 2-38                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-33                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   ├─ModuleList (final_layer): 1-18                        --                        --                        (recursive)               --
#   │    └─MaxNormLinear (1): 2-40                          [1, 32]                   [1, 4]                    132                       --
#   ├─ModuleList (attention_blocks): 1-16                   --                        --                        (recursive)               --
#   │    └─_AttentionBlock (2): 2-41                        [1, 32, 16]               [1, 32, 16]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-35                [1, 32, 16]               [1, 16, 32]               --                        --
#   │    │    └─LayerNorm (ln): 3-36                        [1, 16, 32]               [1, 16, 32]               64                        --
#   │    │    └─_MHA (mha): 3-37                            [1, 16, 32]               [1, 16, 32]               2,128                     --
#   │    │    └─Dropout (drop): 3-38                        [1, 16, 32]               [1, 16, 32]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-39                [1, 16, 32]               [1, 32, 16]               --                        --
#   ├─ModuleList (temporal_conv_nets): 1-17                 --                        --                        (recursive)               --
#   │    └─Sequential (2): 2-42                             [1, 32, 16]               [1, 32, 16]               8,384                     --
#   │    │    └─_TCNResidualBlock (0): 3-40                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (2): 2-52                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-44                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (2): 2-52                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-44                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (2): 2-52                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-46                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (2): 2-52                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-50                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (2): 2-52                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-50                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   ├─ModuleList (final_layer): 1-18                        --                        --                        (recursive)               --
#   │    └─MaxNormLinear (2): 2-54                          [1, 32]                   [1, 4]                    132                       --
#   ├─ModuleList (attention_blocks): 1-16                   --                        --                        (recursive)               --
#   │    └─_AttentionBlock (3): 2-55                        [1, 32, 16]               [1, 32, 16]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-52                [1, 32, 16]               [1, 16, 32]               --                        --
#   │    │    └─LayerNorm (ln): 3-53                        [1, 16, 32]               [1, 16, 32]               64                        --
#   │    │    └─_MHA (mha): 3-54                            [1, 16, 32]               [1, 16, 32]               2,128                     --
#   │    │    └─Dropout (drop): 3-55                        [1, 16, 32]               [1, 16, 32]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-56                [1, 16, 32]               [1, 32, 16]               --                        --
#   ├─ModuleList (temporal_conv_nets): 1-17                 --                        --                        (recursive)               --
#   │    └─Sequential (3): 2-56                             [1, 32, 16]               [1, 32, 16]               8,384                     --
#   │    │    └─_TCNResidualBlock (0): 3-57                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (3): 2-66                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-61                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (3): 2-66                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (0): 3-61                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (3): 2-66                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-63                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (3): 2-66                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-67                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    └─Sequential (3): 2-66                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-67                 --                        --                        (recursive)               4
#   │    └─Sequential (4): 2-67                             --                        --                        (recursive)               --
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   ├─ModuleList (final_layer): 1-18                        --                        --                        (recursive)               --
#   │    └─MaxNormLinear (3): 2-68                          [1, 32]                   [1, 4]                    132                       --
#   ├─ModuleList (attention_blocks): 1-16                   --                        --                        (recursive)               --
#   │    └─_AttentionBlock (4): 2-69                        [1, 32, 16]               [1, 32, 16]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-69                [1, 32, 16]               [1, 16, 32]               --                        --
#   │    │    └─LayerNorm (ln): 3-70                        [1, 16, 32]               [1, 16, 32]               64                        --
#   │    │    └─_MHA (mha): 3-71                            [1, 16, 32]               [1, 16, 32]               2,128                     --
#   │    │    └─Dropout (drop): 3-72                        [1, 16, 32]               [1, 16, 32]               --                        --
#   │    │    └─Rearrange (dimshuffle): 3-73                [1, 16, 32]               [1, 32, 16]               --                        --
#   ├─ModuleList (temporal_conv_nets): 1-17                 --                        --                        (recursive)               --
#   │    └─Sequential (4): 2-70                             [1, 32, 16]               [1, 32, 16]               --                        --
#   │    │    └─_TCNResidualBlock (0): 3-74                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    │    └─_TCNResidualBlock (0): 3-78                 --                        --                        (recursive)               4
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    │    └─_TCNResidualBlock (0): 3-78                 --                        --                        (recursive)               4
#   │    │    └─_TCNResidualBlock (1): 3-79                 --                        --                        (recursive)               4
#   │    │    └─_TCNResidualBlock (1): 3-80                 [1, 32, 16]               [1, 32, 16]               8,384                     4
#   ├─ModuleList (final_layer): 1-18                        --                        --                        (recursive)               --
#   │    └─MaxNormLinear (4): 2-71                          [1, 32]                   [1, 4]                    132                       --
#   ├─Identity (out_fun): 1-19                              [1, 4]                    [1, 4]                    --                        --
#   ===========================================================================================================================================================
#   Total params: 184,996
#   Trainable params: 184,996
#   Non-trainable params: 0
#   Total mult-adds (M): 29.76
#   ===========================================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 7.22
#   Params size (MB): 0.45
#   Estimated Total Size (MB): 7.77
#   ===========================================================================================================================================================,
# )

# %%
print("Train Accuracy: ", atcnet.score(X_train, np.argmax(y_train, axis=1)))
print("Test Accuracy: ", atcnet.score(X_test, np.argmax(y_test, axis=1)))

train_loss = atcnet.history[:, 'train_loss']
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train Accuracy:  0.5300925925925926
# Test Accuracy:  0.5138888888888888

# %%
test_metrics(atcnet)
# Out:
# Accuracy:  0.5138888888888888
# Precision:  0.5072703340166583
# Recall:  0.5138888888888888
# F1:  0.4902171239092941

# %%
callbacks = [("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1))]
conformer = NeuralNetClassifier(module=EEGConformer,
        iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
        iterator_train__transforms=transforms, 
        module__n_chans=22,
        module__n_outputs=4,
        module__n_times=1125,
        module__final_fc_length='auto',
        module__add_log_softmax=False,
        criterion=torch.nn.CrossEntropyLoss,
        optimizer=torch.optim.Adam,
        optimizer__betas=(0.5, 0.999),
        optimizer__lr=0.0001,
        train_split=None,
        iterator_train__shuffle=True,
        batch_size=32,
        callbacks=callbacks,
        device='cuda' if cuda else 'cpu',
        verbose=verbose
        )
# clf.callbacks.append(TrainEndCheckpoint(dirname=save_dir + f'\\S{subject}'))
conformer.fit(X_train, y_train, epochs=100)
# Out:
#   epoch    train_loss      lr      dur
# -------  ------------  ------  -------
#       1        1.4168  0.0001  10.6733
#       2        1.4156  0.0001  10.4969
#       3        1.4034  0.0001  10.6850
#       4        1.3911  0.0001  11.2823
#       5        1.3837  0.0001  11.6047
#       6        1.3670  0.0001  11.9581
#       7        1.3334  0.0001  12.9130
#       8        1.3083  0.0001  12.5795
#       9        1.2924  0.0001  12.8235
#      10        1.2828  0.0001  13.4613
#      11        1.2582  0.0001  13.1901
#      12        1.2560  0.0001  13.6251
#      13        1.2467  0.0001  13.5877
#      14        1.2446  0.0001  13.0746
#      15        1.2334  0.0001  13.2354
#      16        1.2208  0.0001  13.2503
#      17        1.2167  0.0001  13.4557
#      18        1.2144  0.0001  13.6096
#      19        1.2068  0.0001  13.4547
#      20        1.2003  0.0001  13.7066
#      21        1.1874  0.0001  13.5997
#      22        1.1824  0.0001  13.6491
#      23        1.1743  0.0001  13.7754
#      24        1.1544  0.0001  13.7083
#      25        1.1579  0.0001  13.7570
#      26        1.1470  0.0001  13.8942
#      27        1.1374  0.0001  13.9050
#      28        1.1320  0.0001  13.9468
#      29        1.1396  0.0001  14.1038
# <class 'skorch.classifier.NeuralNetClassifier'>[initialized](
#   module_=================================================================================================================================================================
#   Layer (type (var_name):depth-idx)                            Input Shape               Output Shape              Param #                   Kernel Shape
#   ================================================================================================================================================================
#   EEGConformer (EEGConformer)                                  [1, 22, 1125]             [1, 4]                    --                        --
#   ├─_PatchEmbedding (patch_embedding): 1-1                     [1, 1, 22, 1125]          [1, 69, 40]               --                        --
#   │    └─Sequential (shallownet): 2-1                          [1, 1, 22, 1125]          [1, 40, 1, 69]            --                        --
#   │    │    └─Conv2d (0): 3-1                                  [1, 1, 22, 1125]          [1, 40, 22, 1101]         1,040                     [1, 25]
#   │    │    └─Conv2d (1): 3-2                                  [1, 40, 22, 1101]         [1, 40, 1, 1101]          35,240                    [22, 1]
#   │    │    └─BatchNorm2d (2): 3-3                             [1, 40, 1, 1101]          [1, 40, 1, 1101]          80                        --
#   │    │    └─ELU (3): 3-4                                     [1, 40, 1, 1101]          [1, 40, 1, 1101]          --                        --
#   │    │    └─AvgPool2d (4): 3-5                               [1, 40, 1, 1101]          [1, 40, 1, 69]            --                        [1, 75]
#   │    │    └─Dropout (5): 3-6                                 [1, 40, 1, 69]            [1, 40, 1, 69]            --                        --
#   │    └─Sequential (projection): 2-2                          [1, 40, 1, 69]            [1, 69, 40]               --                        --
#   │    │    └─Conv2d (0): 3-7                                  [1, 40, 1, 69]            [1, 40, 1, 69]            1,640                     [1, 1]
#   │    │    └─Rearrange (1): 3-8                               [1, 40, 1, 69]            [1, 69, 40]               --                        --
#   ├─_TransformerEncoder (transformer): 1-2                     [1, 69, 40]               [1, 69, 40]               --                        --
#   │    └─_TransformerEncoderBlock (0): 2-3                     [1, 69, 40]               [1, 69, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-9                            [1, 69, 40]               [1, 69, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-10                           [1, 69, 40]               [1, 69, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (1): 2-4                     [1, 69, 40]               [1, 69, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-11                           [1, 69, 40]               [1, 69, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-12                           [1, 69, 40]               [1, 69, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (2): 2-5                     [1, 69, 40]               [1, 69, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-13                           [1, 69, 40]               [1, 69, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-14                           [1, 69, 40]               [1, 69, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (3): 2-6                     [1, 69, 40]               [1, 69, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-15                           [1, 69, 40]               [1, 69, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-16                           [1, 69, 40]               [1, 69, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (4): 2-7                     [1, 69, 40]               [1, 69, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-17                           [1, 69, 40]               [1, 69, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-18                           [1, 69, 40]               [1, 69, 40]               13,080                    --
#   │    └─_TransformerEncoderBlock (5): 2-8                     [1, 69, 40]               [1, 69, 40]               --                        --
#   │    │    └─_ResidualAdd (0): 3-19                           [1, 69, 40]               [1, 69, 40]               6,640                     --
#   │    │    └─_ResidualAdd (1): 3-20                           [1, 69, 40]               [1, 69, 40]               13,080                    --
#   ├─_FullyConnected (fc): 1-3                                  [1, 69, 40]               [1, 32]                   --                        --
#   │    └─Sequential (fc): 2-9                                  [1, 2760]                 [1, 32]                   --                        --
#   │    │    └─Linear (0): 3-21                                 [1, 2760]                 [1, 256]                  706,816                   --
#   │    │    └─ELU (1): 3-22                                    [1, 256]                  [1, 256]                  --                        --
#   │    │    └─Dropout (2): 3-23                                [1, 256]                  [1, 256]                  --                        --
#   │    │    └─Linear (3): 3-24                                 [1, 256]                  [1, 32]                   8,224                     --
#   │    │    └─ELU (4): 3-25                                    [1, 32]                   [1, 32]                   --                        --
#   │    │    └─Dropout (5): 3-26                                [1, 32]                   [1, 32]                   --                        --
#   ├─_FinalLayer (final_layer): 1-4                             [1, 32]                   [1, 4]                    --                        --
#   │    └─Sequential (final_layer): 2-10                        [1, 32]                   [1, 4]                    --                        --
#   │    │    └─Linear (0): 3-27                                 [1, 32]                   [1, 4]                    132                       --
#   │    │    └─Identity (classification): 3-28                  [1, 4]                    [1, 4]                    --                        --
#   ================================================================================================================================================================
#   Total params: 871,492
#   Trainable params: 871,492
#   Non-trainable params: 0
#   Total mult-adds (M): 64.94
#   ================================================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 9.94
#   Params size (MB): 3.49
#   Estimated Total Size (MB): 13.52
#   ================================================================================================================================================================,
# )

# %%
print("Train Accuracy: ", conformer.score(X_train, np.argmax(y_train, axis=1)))
print("Test Accuracy: ", conformer.score(X_test, np.argmax(y_test, axis=1)))

train_loss = conformer.history[:, 'train_loss']
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train Accuracy:  0.5997685185185185
# Test Accuracy:  0.5625

# %%
test_metrics(conformer)
# Out:
# Accuracy:  0.5625
# Precision:  0.5494703381306658
# Recall:  0.5625
# F1:  0.5443197401805263

# %%
import torch
from braindecode.util import set_random_seeds
from braindecode.models import ShallowFBCSPNet

cuda = torch.cuda.is_available()  # check if GPU is available, if True chooses to use it
device = 'cuda' if cuda else 'cpu'
if cuda:
    torch.backends.cudnn.benchmark = True
seed = 20200220  # random seed to make results reproducible
# Set random seed to be able to reproduce results
set_random_seeds(seed=seed, cuda=cuda)

n_classes=4
# Extract number of chans and time steps from dataset
n_chans = 22
input_window_samples = 1125

model = ShallowFBCSPNet(
    n_chans,
    n_classes,
    input_window_samples=input_window_samples,
    final_conv_length='auto',
)

# Send model to GPU
if cuda:
    model.cuda()
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\util.py:51: UserWarning: torch.backends.cudnn.benchmark was set to True which may results in lack of reproducibility. In some cases to ensure reproducibility you may need to set torch.backends.cudnn.benchmark to False.
#   warn(
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:23: UserWarning: ShallowFBCSPNet: 'input_window_samples' is depreciated. Use 'n_times' instead.
#   warnings.warn(
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:180: UserWarning: LogSoftmax final layer will be removed! Please adjust your loss function accordingly (e.g. CrossEntropyLoss)!
#   warnings.warn("LogSoftmax final layer will be removed! " +

# %%
from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split

from braindecode import EEGClassifier

# These values we found good for shallow network:
lr = 0.0625 * 0.01
weight_decay = 0

# For deep4 they should be:
# lr = 1 * 0.01
# weight_decay = 0.5 * 0.001

batch_size = 64
n_epochs = 100


shallowfbcsp = EEGClassifier(
    model,
    iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
    iterator_train__transforms=transforms, 
    criterion=torch.nn.NLLLoss,
    optimizer=torch.optim.AdamW,
    train_split=None,  # using valid_set for validation
    optimizer__lr=lr,
    optimizer__weight_decay=weight_decay,
    batch_size=batch_size,
    callbacks=[
        "accuracy", ("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1)),
    ],
    device=device,
)
# Model training for a specified number of epochs. `y` is None as it is already supplied
# in the dataset.
shallowfbcsp.fit(X_train, np.argmax(y_train, axis=1), epochs=n_epochs)
# Out:
#   epoch    train_accuracy    train_loss      lr     dur
# -------  ----------------  ------------  ------  ------
#       1            0.4134        1.5786  0.0006  4.6850
#       2            0.4801        1.4211  0.0006  4.5579
#       3            0.5222        1.3283  0.0006  4.2348
#       4            0.5340        1.2721  0.0006  4.1920
#       5            0.5546        1.2206  0.0006  4.0120
#       6            0.5785        1.1871  0.0006  4.7696
#       7            0.5921        1.1586  0.0006  3.9877
#       8            0.5995        1.1239  0.0006  4.4405
#       9            0.6067        1.0988  0.0006  3.9009
#      10            0.6296        1.0599  0.0006  4.3667
#      11            0.6350        1.0323  0.0006  4.0424
#      12            0.6488        1.0309  0.0006  3.7763
#      13            0.6507        1.0034  0.0006  4.1641
#      14            0.6824        1.0028  0.0006  3.8062
#      15            0.6683        0.9722  0.0006  3.8153
#      16            0.6676        0.9493  0.0006  4.3578
#      17            0.6762        0.9578  0.0006  3.7800
#      18            0.6981        0.9353  0.0006  3.8520
#      19            0.7134        0.9359  0.0006  3.6218
#      20            0.7329        0.9100  0.0006  4.0191
#      21            0.7352        0.8906  0.0006  3.7664
#      22            0.7014        0.8830  0.0006  3.7547
#      23            0.7417        0.8915  0.0006  3.7113
#      24            0.7287        0.8520  0.0005  3.7007
#      25            0.7414        0.8670  0.0005  3.6793
#      26            0.7264        0.8707  0.0005  3.5596
#      27            0.7558        0.8517  0.0005  3.6209
#      28            0.7539        0.8274  0.0005  3.8893
#      29            0.7567        0.8000  0.0005  3.6093
#      30            0.7887        0.8066  0.0005  3.9999
#      31            0.7836        0.8054  0.0005  3.5403
#      32            0.7729        0.7853  0.0005  3.5967
#      33            0.7657        0.7801  0.0005  3.8416
#      34            0.7917        0.7720  0.0005  3.5481
#      35            0.7956        0.7416  0.0005  3.8029
#      36            0.7924        0.7537  0.0005  3.5546
#      37            0.8049        0.7450  0.0004  3.9672
#      38            0.8236        0.7309  0.0004  3.4511
#      39            0.8313        0.7244  0.0004  3.9909
#      40            0.8264        0.7260  0.0004  3.5075
#      41            0.8123        0.7061  0.0004  3.8463
#      42            0.8222        0.6854  0.0004  3.4150
#      43            0.8301        0.7122  0.0004  3.6885
#      44            0.8271        0.6716  0.0004  3.4019
#      45            0.8141        0.6840  0.0004  3.8546
#      46            0.8400        0.6958  0.0004  3.4098
#      47            0.8347        0.6886  0.0003  3.6564
#      48            0.8528        0.6633  0.0003  3.3157
#      49            0.8512        0.6636  0.0003  3.7634
#      50            0.8493        0.6445  0.0003  3.4895
#      51            0.8560        0.6430  0.0003  3.7517
#      52            0.8562        0.6409  0.0003  3.4281
#      53            0.8586        0.6099  0.0003  3.8595
#      54            0.8694        0.6268  0.0003  3.4369
#      55            0.8627        0.6109  0.0003  3.5962
#      56            0.8762        0.6042  0.0003  3.4739
#      57            0.8676        0.5958  0.0002  3.8246
#      58            0.8752        0.5956  0.0002  3.2744
#      59            0.8808        0.5878  0.0002  3.7093
#      60            0.8715        0.5991  0.0002  3.3960
#      61            0.8861        0.6001  0.0002  3.6599
#      62            0.8914        0.5723  0.0002  3.4147
#      63            0.8972        0.5764  0.0002  3.7877
#      64            0.8905        0.5741  0.0002  3.5235
#      65            0.8991        0.5585  0.0002  3.4465
#      66            0.9049        0.5712  0.0002  3.7321
#      67            0.8981        0.5597  0.0002  3.3828
#      68            0.9030        0.5602  0.0001  3.5251
#      69            0.8977        0.5328  0.0001  3.4149
#      70            0.9032        0.5298  0.0001  3.6763
#      71            0.9051        0.5548  0.0001  3.3312
#      72            0.9109        0.5344  0.0001  3.4777
#      73            0.9120        0.5325  0.0001  3.4747
#      74            0.9157        0.5386  0.0001  3.8024
#      75            0.9169        0.5106  0.0001  3.3760
#      76            0.9116        0.5115  0.0001  3.4655
#      77            0.9139        0.5304  0.0001  3.3753
#      78            0.9208        0.5282  0.0001  3.3508
#      79            0.9178        0.5203  0.0001  3.6340
#      80            0.9174        0.5129  0.0001  3.3806
#      81            0.9227        0.4979  0.0001  3.5216
#      82            0.9257        0.4951  0.0000  3.3276
#      83            0.9201        0.5101  0.0000  3.6207
#      84            0.9236        0.5084  0.0000  3.4136
#      85            0.9252        0.5119  0.0000  3.8587
#      86            0.9262        0.4977  0.0000  3.2865
#      87            0.9243        0.4914  0.0000  3.4403
#      88            0.9257        0.4928  0.0000  3.4068
#      89            0.9266        0.4903  0.0000  3.7864
#      90            0.9245        0.4929  0.0000  3.4203
#      91            0.9266        0.4973  0.0000  3.6241
#      92            0.9266        0.4950  0.0000  3.3634
#      93            0.9280        0.4844  0.0000  3.5133
#      94            0.9278        0.4773  0.0000  3.4191
#      95            0.9271        0.4911  0.0000  3.7928
#      96            0.9287        0.4870  0.0000  3.2592
#      97            0.9282        0.4932  0.0000  3.6066
#      98            0.9287        0.4626  0.0000  3.3757
#      99            0.9285        0.4892  0.0000  3.5358
#     100            0.9287        0.4902  0.0000  3.2664
# <class 'braindecode.classifier.EEGClassifier'>[initialized](
#   module_=============================================================================================================================================
#   Layer (type (var_name):depth-idx)        Input Shape               Output Shape              Param #                   Kernel Shape
#   ============================================================================================================================================
#   ShallowFBCSPNet (ShallowFBCSPNet)        [1, 22, 1125]             [1, 4]                    --                        --
#   ├─Ensure4d (ensuredims): 1-1             [1, 22, 1125]             [1, 22, 1125, 1]          --                        --
#   ├─Rearrange (dimshuffle): 1-2            [1, 22, 1125, 1]          [1, 1, 1125, 22]          --                        --
#   ├─CombinedConv (conv_time_spat): 1-3     [1, 1, 1125, 22]          [1, 40, 1101, 1]          36,240                    --
#   ├─BatchNorm2d (bnorm): 1-4               [1, 40, 1101, 1]          [1, 40, 1101, 1]          80                        --
#   ├─Expression (conv_nonlin_exp): 1-5      [1, 40, 1101, 1]          [1, 40, 1101, 1]          --                        --
#   ├─AvgPool2d (pool): 1-6                  [1, 40, 1101, 1]          [1, 40, 69, 1]            --                        [75, 1]
#   ├─Expression (pool_nonlin_exp): 1-7      [1, 40, 69, 1]            [1, 40, 69, 1]            --                        --
#   ├─Dropout (drop): 1-8                    [1, 40, 69, 1]            [1, 40, 69, 1]            --                        --
#   ├─Sequential (final_layer): 1-9          [1, 40, 69, 1]            [1, 4]                    --                        --
#   │    └─Conv2d (conv_classifier): 2-1     [1, 40, 69, 1]            [1, 4, 1, 1]              11,044                    [69, 1]
#   │    └─LogSoftmax (logsoftmax): 2-2      [1, 4, 1, 1]              [1, 4, 1, 1]              --                        --
#   │    └─Expression (squeeze): 2-3         [1, 4, 1, 1]              [1, 4]                    --                        --
#   ============================================================================================================================================
#   Total params: 47,364
#   Trainable params: 47,364
#   Non-trainable params: 0
#   Total mult-adds (M): 0.01
#   ============================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 0.35
#   Params size (MB): 0.04
#   Estimated Total Size (MB): 0.50
#   ============================================================================================================================================,
# )

# %%
loss = []
acc = []
for a in shallowfbcsp.history:
    loss.append(a['train_loss'])    
    acc.append(a['train_accuracy'])
plt.plot(loss, label='Training Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.plot(acc, label='Training Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
shallowfbcsp.score(X_test, np.argmax(y_test, axis=1))
# Out:
# 0.6296296296296297

# %%
test_metrics(shallowfbcsp)
# Out:
# Accuracy:  0.6296296296296297
# Precision:  0.6302102624729181
# Recall:  0.6296296296296297
# F1:  0.6296048591879575

# %%
from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split

from braindecode import EEGClassifier

# These values we found good for shallow network:
lr = 0.0625 * 0.01
weight_decay = 0


# For deep4 they should be:
# lr = 1 * 0.01
# weight_decay = 0.5 * 0.001

model = EEGNetv4(
    n_chans,
    n_classes,
    input_window_samples=input_window_samples,
    final_conv_length='auto',
)


batch_size = 64
n_epochs = 100

eegnetv4 = EEGClassifier(
    model,
    iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
    iterator_train__transforms=transforms, 
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.AdamW,
    train_split=None,  # using valid_set for validation
    optimizer__lr=lr,
    optimizer__weight_decay=weight_decay,
    batch_size=batch_size,
    callbacks=[
        "accuracy", ("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1)),
    ],
    device=device,
)
# Model training for a specified number of epochs. `y` is None as it is already supplied
# in the dataset.
eegnetv4.fit(X_train, np.argmax(y_train, axis=1), epochs=n_epochs)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:23: UserWarning: EEGNetv4: 'input_window_samples' is depreciated. Use 'n_times' instead.
#   warnings.warn(
#   epoch    train_accuracy    train_loss      lr     dur
# -------  ----------------  ------------  ------  ------
#       1            0.2502        1.4422  0.0006  5.6325
#       2            0.2498        1.3992  0.0006  5.2484
#       3            0.2505        1.3790  0.0006  4.9631
#       4            0.2799        1.3442  0.0006  4.7969
#       5            0.3671        1.3141  0.0006  4.7470
#       6            0.4391        1.2808  0.0006  4.9025
#       7            0.4637        1.2663  0.0006  4.6857
#       8            0.4873        1.2472  0.0006  4.6415
#       9            0.4940        1.2113  0.0006  4.6877
#      10            0.5162        1.1946  0.0006  4.5867
#      11            0.5215        1.1820  0.0006  4.6182
#      12            0.5322        1.1573  0.0006  4.6030
#      13            0.5250        1.1566  0.0006  4.7490
#      14            0.5336        1.1468  0.0006  4.5980
#      15            0.5477        1.1383  0.0006  4.5673
#      16            0.5447        1.1381  0.0006  4.8501
#      17            0.5477        1.1333  0.0006  4.8053
#      18            0.5660        1.1311  0.0006  4.5541
#      19            0.5546        1.1265  0.0006  4.4270
#      20            0.5630        1.1055  0.0006  4.6865
#      21            0.5701        1.1148  0.0006  4.6305
#      22            0.5801        1.1176  0.0006  4.6334
#      87            0.6428        1.0048  0.0000  4.3585
#      88            0.6398        1.0040  0.0000  4.3685
#      89            0.6394        1.0132  0.0000  4.5213
#      90            0.6394        1.0039  0.0000  4.4803
#      91            0.6396        1.0111  0.0000  4.3299
#      92            0.6431        1.0216  0.0000  4.6242
#      93            0.6421        1.0033  0.0000  4.4915
#      94            0.6431        1.0047  0.0000  4.3179
#      95            0.6421        1.0017  0.0000  4.5008
#      96            0.6419        1.0107  0.0000  4.2409
#      97            0.6421        1.0101  0.0000  4.4018
#      98            0.6426        1.0175  0.0000  4.4842
#      99            0.6431        1.0099  0.0000  4.4370
#     100            0.6426        0.9969  0.0000  4.4986
# <class 'braindecode.classifier.EEGClassifier'>[initialized](
#   module_=======================================================================================================================================================
#   Layer (type (var_name):depth-idx)                  Input Shape               Output Shape              Param #                   Kernel Shape
#   ======================================================================================================================================================
#   EEGNetv4 (EEGNetv4)                                [1, 22, 1125]             [1, 4]                    --                        --
#   ├─Ensure4d (ensuredims): 1-1                       [1, 22, 1125]             [1, 22, 1125, 1]          --                        --
#   ├─Rearrange (dimshuffle): 1-2                      [1, 22, 1125, 1]          [1, 1, 22, 1125]          --                        --
#   ├─Conv2d (conv_temporal): 1-3                      [1, 1, 22, 1125]          [1, 8, 22, 1126]          512                       [1, 64]
#   ├─BatchNorm2d (bnorm_temporal): 1-4                [1, 8, 22, 1126]          [1, 8, 22, 1126]          16                        --
#   ├─Conv2dWithConstraint (conv_spatial): 1-5         [1, 8, 22, 1126]          [1, 16, 1, 1126]          352                       [22, 1]
#   ├─BatchNorm2d (bnorm_1): 1-6                       [1, 16, 1, 1126]          [1, 16, 1, 1126]          32                        --
#   ├─Expression (elu_1): 1-7                          [1, 16, 1, 1126]          [1, 16, 1, 1126]          --                        --
#   ├─AvgPool2d (pool_1): 1-8                          [1, 16, 1, 1126]          [1, 16, 1, 281]           --                        [1, 4]
#   ├─Dropout (drop_1): 1-9                            [1, 16, 1, 281]           [1, 16, 1, 281]           --                        --
#   ├─Conv2d (conv_separable_depth): 1-10              [1, 16, 1, 281]           [1, 16, 1, 282]           256                       [1, 16]
#   ├─Conv2d (conv_separable_point): 1-11              [1, 16, 1, 282]           [1, 16, 1, 282]           256                       [1, 1]
#   ├─BatchNorm2d (bnorm_2): 1-12                      [1, 16, 1, 282]           [1, 16, 1, 282]           32                        --
#   ├─Expression (elu_2): 1-13                         [1, 16, 1, 282]           [1, 16, 1, 282]           --                        --
#   ├─AvgPool2d (pool_2): 1-14                         [1, 16, 1, 282]           [1, 16, 1, 35]            --                        [1, 8]
#   ├─Dropout (drop_2): 1-15                           [1, 16, 1, 35]            [1, 16, 1, 35]            --                        --
#   ├─Sequential (final_layer): 1-16                   [1, 16, 1, 35]            [1, 4]                    --                        --
#   │    └─Conv2d (conv_classifier): 2-1               [1, 16, 1, 35]            [1, 4, 1, 1]              2,244                     [1, 35]
#   │    └─Rearrange (permute_back): 2-2               [1, 4, 1, 1]              [1, 4, 1, 1]              --                        --
#   │    └─Expression (squeeze): 2-3                   [1, 4, 1, 1]              [1, 4]                    --                        --
#   ======================================================================================================================================================
#   Total params: 3,700
#   Trainable params: 3,700
#   Non-trainable params: 0
#   Total mult-adds (M): 13.23
#   ======================================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 3.57
#   Params size (MB): 0.01
#   Estimated Total Size (MB): 3.68
#   ======================================================================================================================================================,
# )

# %%
loss = []
acc = []
for a in eegnetv4.history:
    loss.append(a['train_loss'])    
    acc.append(a['train_accuracy'])
plt.plot(loss, label='Training Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.plot(acc, label='Training Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
eegnetv4.score(X_test, np.argmax(y_test, axis=1))
# Out:
# 0.6377314814814815

# %%
test_metrics(eegnetv4)
# Out:
# Accuracy:  0.6377314814814815
# Precision:  0.6442663740308324
# Recall:  0.6377314814814815
# F1:  0.6338472494359132

# %%
from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split

from braindecode import EEGClassifier

# These values we found good for shallow network:
lr = 0.0625 * 0.01
weight_decay = 0

model = EEGNetv1(
    n_chans,
    n_classes,
    input_window_samples=input_window_samples,
    final_conv_length='auto',
)

# For deep4 they should be:
lr = 1 * 0.01
weight_decay = 0.5 * 0.001

batch_size = 64
n_epochs = 100

eegnetv1 = EEGClassifier(
    model,
    iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
    iterator_train__transforms=transforms, 
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.AdamW,
    train_split=None,  # using valid_set for validation
    optimizer__lr=lr,
    optimizer__weight_decay=weight_decay,
    batch_size=batch_size,
    callbacks=[
        "accuracy", ("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1)),
    ],
    device=device,
)
# Model training for a specified number of epochs. `y` is None as it is already supplied
# in the dataset.
eegnetv1.fit(X_train, np.argmax(y_train, axis=1), epochs=n_epochs)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:23: UserWarning: EEGNetv1: 'input_window_samples' is depreciated. Use 'n_times' instead.
#   warnings.warn(
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:180: UserWarning: LogSoftmax final layer will be removed! Please adjust your loss function accordingly (e.g. CrossEntropyLoss)!
#   warnings.warn("LogSoftmax final layer will be removed! " +
#   epoch    train_accuracy    train_loss      lr     dur
# -------  ----------------  ------------  ------  ------
#       1            0.2699        2.2511  0.0100  5.9688
#       2            0.3495        1.3915  0.0100  5.3635
#       3            0.4076        1.3306  0.0100  5.3331
#       4            0.4701        1.2891  0.0100  5.5555
#       5            0.4294        1.2177  0.0100  5.4623
#       6            0.4759        1.1903  0.0099  5.4363
#       7            0.4868        1.1771  0.0099  5.4957
#       8            0.5069        1.1470  0.0099  5.4309
#       9            0.5287        1.1296  0.0098  5.4780
#      10            0.4769        1.1248  0.0098  5.4634
#      11            0.4979        1.1351  0.0098  5.5395
#      12            0.4567        1.1122  0.0097  5.3321
#      13            0.5053        1.1024  0.0096  5.5307
#      14            0.5400        1.1052  0.0096  5.5132
#      15            0.5444        1.0959  0.0095  5.3728
#      16            0.5412        1.0912  0.0094  5.5060
#      17            0.5523        1.0702  0.0094  5.3957
#      18            0.4975        1.0680  0.0093  5.3717
#      19            0.5644        1.0614  0.0092  5.5058
#      20            0.5563        1.0512  0.0091  5.5232
#      21            0.5956        1.0565  0.0090  5.4839
#      22            0.5458        1.0537  0.0089  5.4933
#      23            0.5731        1.0530  0.0088  5.4515
#      24            0.5808        1.0470  0.0087  5.3448
#      25            0.5792        1.0478  0.0086  5.4073
#      26            0.5912        1.0456  0.0085  5.4451
#      27            0.5157        1.0300  0.0084  5.5885
#      28            0.6081        1.0450  0.0083  5.3538
#      29            0.6035        1.0381  0.0082  5.5097
#      30            0.5884        1.0069  0.0080  5.3831
#      31            0.5396        1.0093  0.0079  5.4691
#      96            0.6382        0.8869  0.0000  5.4174
#      97            0.6380        0.8811  0.0000  5.4279
#      98            0.6373        0.8921  0.0000  5.5600
#      99            0.6373        0.8846  0.0000  5.4203
#     100            0.6370        0.8880  0.0000  5.4606
# <class 'braindecode.classifier.EEGClassifier'>[initialized](
#   module_=============================================================================================================================================
#   Layer (type (var_name):depth-idx)        Input Shape               Output Shape              Param #                   Kernel Shape
#   ============================================================================================================================================
#   EEGNetv1 (EEGNetv1)                      [1, 22, 1125]             [1, 4]                    --                        --
#   ├─Ensure4d (ensuredims): 1-1             [1, 22, 1125]             [1, 22, 1125, 1]          --                        --
#   ├─Conv2d (conv_1): 1-2                   [1, 22, 1125, 1]          [1, 16, 1125, 1]          368                       [1, 1]
#   ├─BatchNorm2d (bnorm_1): 1-3             [1, 16, 1125, 1]          [1, 16, 1125, 1]          32                        --
#   ├─Expression (elu_1): 1-4                [1, 16, 1125, 1]          [1, 16, 1125, 1]          --                        --
#   ├─Expression (permute_1): 1-5            [1, 16, 1125, 1]          [1, 1, 16, 1125]          --                        --
#   ├─Dropout (drop_1): 1-6                  [1, 1, 16, 1125]          [1, 1, 16, 1125]          --                        --
#   ├─Conv2d (conv_2): 1-7                   [1, 1, 16, 1125]          [1, 4, 17, 1094]          260                       [2, 32]
#   ├─BatchNorm2d (bnorm_2): 1-8             [1, 4, 17, 1094]          [1, 4, 17, 1094]          8                         --
#   ├─Expression (elu_2): 1-9                [1, 4, 17, 1094]          [1, 4, 17, 1094]          --                        --
#   ├─MaxPool2d (pool_2): 1-10               [1, 4, 17, 1094]          [1, 4, 8, 273]            --                        [2, 4]
#   ├─Dropout (drop_2): 1-11                 [1, 4, 8, 273]            [1, 4, 8, 273]            --                        --
#   ├─Conv2d (conv_3): 1-12                  [1, 4, 8, 273]            [1, 4, 9, 270]            516                       [8, 4]
#   ├─BatchNorm2d (bnorm_3): 1-13            [1, 4, 9, 270]            [1, 4, 9, 270]            8                         --
#   ├─Expression (elu_3): 1-14               [1, 4, 9, 270]            [1, 4, 9, 270]            --                        --
#   ├─MaxPool2d (pool_3): 1-15               [1, 4, 9, 270]            [1, 4, 4, 67]             --                        [2, 4]
#   ├─Dropout (drop_3): 1-16                 [1, 4, 4, 67]             [1, 4, 4, 67]             --                        --
#   ├─Sequential (final_layer): 1-17         [1, 4, 4, 67]             [1, 4]                    --                        --
#   │    └─Conv2d (conv_classifier): 2-1     [1, 4, 4, 67]             [1, 4, 1, 1]              4,292                     [4, 67]
#   │    └─LogSoftmax (softmax): 2-2         [1, 4, 1, 1]              [1, 4, 1, 1]              --                        --
#   │    └─Rearrange (permute_2): 2-3        [1, 4, 1, 1]              [1, 4, 1, 1]              --                        --
#   │    └─Expression (squeeze): 2-4         [1, 4, 1, 1]              [1, 4]                    --                        --
#   ============================================================================================================================================
#   Total params: 5,484
#   Trainable params: 5,484
#   Non-trainable params: 0
#   Total mult-adds (M): 6.51
#   ============================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 1.63
#   Params size (MB): 0.02
#   Estimated Total Size (MB): 1.75
#   ============================================================================================================================================,
# )

# %%
loss = []
acc = []
for a in eegnetv1.history:
    loss.append(a['train_loss'])    
    acc.append(a['train_accuracy'])
plt.plot(loss, label='Training Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.plot(acc, label='Training Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
eegnetv1.score(X_test, np.argmax(y_test, axis=1))
# Out:
# 0.5648148148148148

# %%
test_metrics(eegnetv1)
# Out:
# Accuracy:  0.5648148148148148
# Precision:  0.6177733027585666
# Recall:  0.5648148148148148
# F1:  0.5490981695810621

# %%
from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split

from braindecode import EEGClassifier

# These values we found good for shallow network:
lr = 0.0625 * 0.01
weight_decay = 0

model = Deep4Net(
    n_chans,
    n_classes,
    input_window_samples=input_window_samples,
    final_conv_length='auto',
)

# For deep4 they should be:
lr = 1 * 0.01
weight_decay = 0.5 * 0.001

batch_size = 64
n_epochs = 100

deep4net = EEGClassifier(
    model,
    iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
    iterator_train__transforms=transforms, 
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.AdamW,
    train_split=None,  # using valid_set for validation
    optimizer__lr=lr,
    optimizer__weight_decay=weight_decay,
    batch_size=batch_size,
    callbacks=[
        "accuracy", ("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1)),
    ],
    device=device,
)
# Model training for a specified number of epochs. `y` is None as it is already supplied
# in the dataset.
deep4net.fit(X_train, np.argmax(y_train, axis=1), epochs=n_epochs)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:23: UserWarning: Deep4Net: 'input_window_samples' is depreciated. Use 'n_times' instead.
#   warnings.warn(
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:180: UserWarning: LogSoftmax final layer will be removed! Please adjust your loss function accordingly (e.g. CrossEntropyLoss)!
#   warnings.warn("LogSoftmax final layer will be removed! " +
#   epoch    train_accuracy    train_loss      lr     dur
# -------  ----------------  ------------  ------  ------
#       1            0.2632        2.7558  0.0100  4.5211
#       2            0.2843        1.6808  0.0100  4.3698
#       3            0.2743        1.5107  0.0100  3.9693
#       4            0.3539        1.4475  0.0100  4.2201
#       5            0.3574        1.3509  0.0100  3.8619
#       6            0.3887        1.3520  0.0099  4.2153
#       7            0.3870        1.2778  0.0099  4.0961
#       8            0.4238        1.2719  0.0099  3.8030
#       9            0.4340        1.2549  0.0098  3.8529
#      10            0.4609        1.2316  0.0098  4.0170
#      11            0.5065        1.1996  0.0098  3.6181
#      12            0.4817        1.1782  0.0097  3.9423
#      13            0.5231        1.1637  0.0096  3.7698
#      14            0.5074        1.1620  0.0096  4.0203
#      15            0.5086        1.1371  0.0095  3.7946
#      16            0.5273        1.1445  0.0094  3.8151
#      17            0.5396        1.1445  0.0094  3.6745
#      18            0.5294        1.1207  0.0093  3.9336
#      19            0.5398        1.1253  0.0092  3.6708
#      20            0.5354        1.1239  0.0091  3.6795
#      21            0.5141        1.1164  0.0090  3.8214
#      22            0.5525        1.1047  0.0089  3.7886
#      23            0.5400        1.0954  0.0088  3.6858
#      24            0.5838        1.0898  0.0087  3.6634
#      25            0.5731        1.0794  0.0086  3.5948
#      26            0.5847        1.0926  0.0085  3.7384
#      27            0.5725        1.0730  0.0084  3.6231
#      28            0.5613        1.0765  0.0083  3.6593
#      29            0.5576        1.0686  0.0082  3.7348
#      30            0.6000        1.0695  0.0080  3.6543
#      31            0.6005        1.0684  0.0079  3.7501
#      32            0.6109        1.0503  0.0078  3.6000
#      33            0.6125        1.0514  0.0076  3.6663
#      34            0.6269        1.0516  0.0075  3.6121
#      35            0.6069        1.0498  0.0074  3.6773
#      36            0.6412        1.0449  0.0072  3.6342
#      37            0.6456        1.0278  0.0071  3.7133
#      38            0.6433        1.0377  0.0069  3.6606
#      39            0.6627        1.0243  0.0068  3.4993
#      40            0.6722        1.0021  0.0066  3.6534
#      41            0.6789        1.0123  0.0065  3.4727
#      42            0.6683        1.0044  0.0063  3.7105
#      43            0.6863        0.9799  0.0062  3.5718
#      44            0.6259        0.9889  0.0060  3.5909
#      45            0.6935        0.9906  0.0059  3.4008
#      46            0.7213        1.0003  0.0057  3.5292
#      47            0.6972        0.9864  0.0056  3.5390
#      48            0.7280        0.9868  0.0054  3.5522
#      49            0.6977        0.9596  0.0052  3.4675
#      50            0.7213        0.9484  0.0051  3.6720
#      51            0.7301        0.9640  0.0049  3.6729
#      52            0.7558        0.9353  0.0048  3.5626
#      53            0.7410        0.9455  0.0046  3.6061
#      54            0.7347        0.9297  0.0044  3.5287
#      55            0.7507        0.9220  0.0043  3.5537
#      56            0.7678        0.9216  0.0041  3.3345
#      57            0.7475        0.9088  0.0040  3.5582
#      58            0.7711        0.9076  0.0038  3.4083
#      59            0.7597        0.8950  0.0037  3.6037
#      60            0.7817        0.8825  0.0035  3.5321
#      61            0.8042        0.8900  0.0034  3.5362
#      62            0.7910        0.8861  0.0032  3.3644
#      63            0.7975        0.8880  0.0031  3.5206
#      64            0.8310        0.8574  0.0029  3.4779
#      65            0.8125        0.8732  0.0028  3.6161
#      66            0.8352        0.8635  0.0026  3.6071
#      67            0.8384        0.8600  0.0025  3.4823
#      68            0.8519        0.8360  0.0024  3.5044
#      69            0.8426        0.8339  0.0022  3.3817
#      70            0.8495        0.8359  0.0021  3.4721
#      71            0.8391        0.8316  0.0020  3.3761
#      72            0.8623        0.8229  0.0018  3.4863
#      73            0.8806        0.8109  0.0017  3.4588
#      74            0.8824        0.8018  0.0016  3.5170
#      75            0.8750        0.7833  0.0015  3.5051
#      76            0.8806        0.7979  0.0014  3.5106
#      77            0.8924        0.7924  0.0013  3.5214
#      78            0.8894        0.7786  0.0012  3.5856
#      79            0.8803        0.7841  0.0011  3.5317
#      80            0.8912        0.7809  0.0010  3.5464
#      81            0.8917        0.7817  0.0009  3.6029
#      82            0.8954        0.7783  0.0008  3.4102
#      83            0.8903        0.7617  0.0007  3.5072
#      84            0.8947        0.7561  0.0006  3.5240
#      85            0.9060        0.7534  0.0006  3.4424
#      86            0.9042        0.7455  0.0005  3.5642
#      87            0.9065        0.7586  0.0004  3.5221
#      88            0.9044        0.7558  0.0004  3.5223
#      89            0.9049        0.7528  0.0003  3.4945
#      90            0.9060        0.7435  0.0002  3.5157
#      91            0.9111        0.7331  0.0002  3.4828
#      92            0.9095        0.7446  0.0002  3.3695
#      93            0.9127        0.7324  0.0001  3.4367
#      94            0.9127        0.7434  0.0001  3.5229
#      95            0.9097        0.7187  0.0001  3.5212
#      96            0.9088        0.7258  0.0000  3.5151
#      97            0.9093        0.7441  0.0000  3.5414
#      98            0.9120        0.7195  0.0000  3.3827
#      99            0.9088        0.7201  0.0000  3.4748
#     100            0.9111        0.7381  0.0000  3.4305
# <class 'braindecode.classifier.EEGClassifier'>[initialized](
#   module_=============================================================================================================================================
#   Layer (type (var_name):depth-idx)        Input Shape               Output Shape              Param #                   Kernel Shape
#   ============================================================================================================================================
#   Deep4Net (Deep4Net)                      [1, 22, 1125]             [1, 4]                    --                        --
#   ├─Ensure4d (ensuredims): 1-1             [1, 22, 1125]             [1, 22, 1125, 1]          --                        --
#   ├─Rearrange (dimshuffle): 1-2            [1, 22, 1125, 1]          [1, 1, 1125, 22]          --                        --
#   ├─CombinedConv (conv_time_spat): 1-3     [1, 1, 1125, 22]          [1, 25, 1116, 1]          14,025                    --
#   ├─BatchNorm2d (bnorm): 1-4               [1, 25, 1116, 1]          [1, 25, 1116, 1]          50                        --
#   ├─Expression (conv_nonlin): 1-5          [1, 25, 1116, 1]          [1, 25, 1116, 1]          --                        --
#   ├─MaxPool2d (pool): 1-6                  [1, 25, 1116, 1]          [1, 25, 372, 1]           --                        [3, 1]
#   ├─Expression (pool_nonlin): 1-7          [1, 25, 372, 1]           [1, 25, 372, 1]           --                        --
#   ├─Dropout (drop_2): 1-8                  [1, 25, 372, 1]           [1, 25, 372, 1]           --                        --
#   ├─Conv2d (conv_2): 1-9                   [1, 25, 372, 1]           [1, 50, 363, 1]           12,500                    [10, 1]
#   ├─BatchNorm2d (bnorm_2): 1-10            [1, 50, 363, 1]           [1, 50, 363, 1]           100                       --
#   ├─Expression (nonlin_2): 1-11            [1, 50, 363, 1]           [1, 50, 363, 1]           --                        --
#   ├─MaxPool2d (pool_2): 1-12               [1, 50, 363, 1]           [1, 50, 121, 1]           --                        [3, 1]
#   ├─Expression (pool_nonlin_2): 1-13       [1, 50, 121, 1]           [1, 50, 121, 1]           --                        --
#   ├─Dropout (drop_3): 1-14                 [1, 50, 121, 1]           [1, 50, 121, 1]           --                        --
#   ├─Conv2d (conv_3): 1-15                  [1, 50, 121, 1]           [1, 100, 112, 1]          50,000                    [10, 1]
#   ├─BatchNorm2d (bnorm_3): 1-16            [1, 100, 112, 1]          [1, 100, 112, 1]          200                       --
#   ├─Expression (nonlin_3): 1-17            [1, 100, 112, 1]          [1, 100, 112, 1]          --                        --
#   ├─MaxPool2d (pool_3): 1-18               [1, 100, 112, 1]          [1, 100, 37, 1]           --                        [3, 1]
#   ├─Expression (pool_nonlin_3): 1-19       [1, 100, 37, 1]           [1, 100, 37, 1]           --                        --
#   ├─Dropout (drop_4): 1-20                 [1, 100, 37, 1]           [1, 100, 37, 1]           --                        --
#   ├─Conv2d (conv_4): 1-21                  [1, 100, 37, 1]           [1, 200, 28, 1]           200,000                   [10, 1]
#   ├─BatchNorm2d (bnorm_4): 1-22            [1, 200, 28, 1]           [1, 200, 28, 1]           400                       --
#   ├─Expression (nonlin_4): 1-23            [1, 200, 28, 1]           [1, 200, 28, 1]           --                        --
#   ├─MaxPool2d (pool_4): 1-24               [1, 200, 28, 1]           [1, 200, 9, 1]            --                        [3, 1]
#   ├─Expression (pool_nonlin_4): 1-25       [1, 200, 9, 1]            [1, 200, 9, 1]            --                        --
#   ├─Sequential (final_layer): 1-26         [1, 200, 9, 1]            [1, 4]                    --                        --
#   │    └─Conv2d (conv_classifier): 2-1     [1, 200, 9, 1]            [1, 4, 1, 1]              7,204                     [9, 1]
#   │    └─LogSoftmax (logsoftmax): 2-2      [1, 4, 1, 1]              [1, 4, 1, 1]              --                        --
#   │    └─Expression (squeeze): 2-3         [1, 4, 1, 1]              [1, 4]                    --                        --
#   ============================================================================================================================================
#   Total params: 284,479
#   Trainable params: 284,479
#   Non-trainable params: 0
#   Total mult-adds (M): 15.75
#   ============================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 0.78
#   Params size (MB): 1.08
#   Estimated Total Size (MB): 1.96
#   ============================================================================================================================================,
# )

# %%
loss = []
acc = []
for a in deep4net.history:
    loss.append(a['train_loss'])    
    acc.append(a['train_accuracy'])
plt.plot(loss, label='Training Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.plot(acc, label='Training Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
deep4net.score(X_test, np.argmax(y_test, axis=1))
# Out:
# 0.5752314814814815

# %%
test_metrics(deep4net)
# Out:
# Accuracy:  0.5752314814814815
# Precision:  0.5777345657405133
# Recall:  0.5752314814814815
# F1:  0.5704220880694076

# %%
from skorch.callbacks import LRScheduler
from skorch.helper import predefined_split

from braindecode import EEGClassifier

# These values we found good for shallow network:
lr = 0.0625 * 0.01
weight_decay = 0

model = EEGITNet(

    n_classes,
        n_chans,
    input_window_samples=input_window_samples,
)

# For deep4 they should be:
lr = 1 * 0.01
weight_decay = 0.5 * 0.001

batch_size = 64
n_epochs = 100

eegitnet = EEGClassifier(
    model,
    iterator_train=AugmentedDataLoader,  # This tells EEGClassifier to use a custom DataLoader
    iterator_train__transforms=transforms, 
    criterion=torch.nn.CrossEntropyLoss,
    optimizer=torch.optim.AdamW,
    train_split=None,  # using valid_set for validation
    optimizer__lr=lr,
    optimizer__weight_decay=weight_decay,
    batch_size=batch_size,
    callbacks=[
        "accuracy", ("lr_scheduler", LRScheduler('CosineAnnealingLR', T_max=n_epochs - 1)),
    ],
    device=device,
)
# Model training for a specified number of epochs. `y` is None as it is already supplied
# in the dataset.
eegitnet.fit(X_train, np.argmax(y_train, axis=1), epochs=n_epochs)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:23: UserWarning: EEGITNet: 'input_window_samples' is depreciated. Use 'n_times' instead.
#   warnings.warn(
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\braindecode\models\base.py:180: UserWarning: LogSoftmax final layer will be removed! Please adjust your loss function accordingly (e.g. CrossEntropyLoss)!
#   warnings.warn("LogSoftmax final layer will be removed! " +
#   epoch    train_accuracy    train_loss      lr     dur
# -------  ----------------  ------------  ------  ------
#       1            0.2812        1.6573  0.0100  4.8291
#       2            0.3382        1.4453  0.0100  4.4222
#       3            0.3456        1.3430  0.0100  4.4665
#       4            0.4100        1.2987  0.0100  4.5503
#       5            0.4396        1.2684  0.0100  4.7212
#       6            0.4718        1.2323  0.0099  4.7090
#       7            0.4600        1.2158  0.0099  4.8147
#       8            0.4426        1.1992  0.0099  5.0941
#       9            0.4699        1.1815  0.0098  4.9622
#      10            0.4618        1.1841  0.0098  5.0952
#      11            0.5292        1.1642  0.0098  5.0545
#      12            0.4674        1.1832  0.0097  5.2324
#      13            0.5278        1.1541  0.0096  5.0818
#      14            0.5331        1.1634  0.0096  5.2349
#      15            0.5394        1.1615  0.0095  5.0262
#      16            0.5380        1.1580  0.0094  5.3321
#      17            0.5498        1.1416  0.0094  5.0650
#      18            0.5377        1.1368  0.0093  5.1936
#      19            0.5477        1.1428  0.0092  5.2709
#      20            0.5363        1.1217  0.0091  5.3202
#      85            0.7141        0.9275  0.0006  5.5613
#      86            0.7153        0.9331  0.0005  5.4605
#      87            0.7127        0.9245  0.0004  5.4353
#      88            0.7106        0.9282  0.0004  5.5405
#      89            0.7164        0.9204  0.0003  5.5316
#      90            0.7160        0.9206  0.0002  5.1938
#      91            0.7174        0.9368  0.0002  5.5427
#      92            0.7157        0.9265  0.0002  5.4829
#      93            0.7125        0.9250  0.0001  5.3758
#      94            0.7150        0.9239  0.0001  5.3670
#      95            0.7167        0.9251  0.0001  5.4084
#      96            0.7160        0.9249  0.0000  5.4186
#      97            0.7134        0.9134  0.0000  5.5213
#      98            0.7141        0.9245  0.0000  5.7634
#      99            0.7155        0.9108  0.0000  5.7598
#     100            0.7127        0.9231  0.0000  5.8644
# <class 'braindecode.classifier.EEGClassifier'>[initialized](
#   module_=======================================================================================================================================================
#   Layer (type (var_name):depth-idx)                  Input Shape               Output Shape              Param #                   Kernel Shape
#   ======================================================================================================================================================
#   EEGITNet (EEGITNet)                                [1, 22, 1125]             [1, 4]                    --                        --
#   ├─Sequential (input_preprocess): 1-1               [1, 22, 1125]             [1, 1, 22, 1125]          --                        --
#   │    └─Ensure4d (0): 2-1                           [1, 22, 1125]             [1, 22, 1125, 1]          --                        --
#   │    └─Rearrange (1): 2-2                          [1, 22, 1125, 1]          [1, 1, 22, 1125]          --                        --
#   ├─_InceptionBlock (inception_block): 1-2           [1, 1, 22, 1125]          [1, 14, 1, 1125]          --                        --
#   │    └─ModuleList (branches): 2-3                  --                        --                        --                        --
#   │    │    └─Sequential (0): 3-1                    [1, 1, 22, 1125]          [1, 2, 1, 1125]           84                        --
#   │    │    └─Sequential (1): 3-2                    [1, 1, 22, 1125]          [1, 4, 1, 1125]           232                       --
#   │    │    └─Sequential (2): 3-3                    [1, 1, 22, 1125]          [1, 8, 1, 1125]           720                       --
#   ├─Sequential (pooling): 1-3                        [1, 14, 1, 1125]          [1, 14, 1, 281]           --                        --
#   │    └─AvgPool2d (0): 2-4                          [1, 14, 1, 1125]          [1, 14, 1, 281]           --                        [1, 4]
#   │    └─Dropout (1): 2-5                            [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   ├─_TCBlock (TC_block1): 1-4                        [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc1): 2-6                       [1, 14, 1, 284]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-4              [1, 14, 1, 284]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-5                   [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-6                           [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-7                       [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc2): 2-7                       [1, 14, 1, 284]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-8              [1, 14, 1, 284]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-9                   [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-10                          [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-11                      [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   ├─_TCBlock (TC_block2): 1-5                        [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc1): 2-8                       [1, 14, 1, 287]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-12             [1, 14, 1, 287]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-13                  [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-14                          [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-15                      [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc2): 2-9                       [1, 14, 1, 287]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-16             [1, 14, 1, 287]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-17                  [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-18                          [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-19                      [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   ├─_TCBlock (TC_block3): 1-6                        [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc1): 2-10                      [1, 14, 1, 293]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-20             [1, 14, 1, 293]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-21                  [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-22                          [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-23                      [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc2): 2-11                      [1, 14, 1, 293]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-24             [1, 14, 1, 293]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-25                  [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-26                          [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-27                      [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   ├─_TCBlock (TC_block4): 1-7                        [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc1): 2-12                      [1, 14, 1, 305]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-28             [1, 14, 1, 305]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-29                  [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-30                          [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-31                      [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    └─Sequential (tc2): 2-13                      [1, 14, 1, 305]           [1, 14, 1, 281]           --                        --
#   │    │    └─_DepthwiseConv2d (0): 3-32             [1, 14, 1, 305]           [1, 14, 1, 281]           56                        [1, 4]
#   │    │    └─BatchNorm2d (1): 3-33                  [1, 14, 1, 281]           [1, 14, 1, 281]           28                        --
#   │    │    └─ELU (2): 3-34                          [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   │    │    └─Dropout (3): 3-35                      [1, 14, 1, 281]           [1, 14, 1, 281]           --                        --
#   ├─Sequential (dim_reduction): 1-8                  [1, 14, 1, 281]           [1, 28, 1, 70]            --                        --
#   │    └─Conv2d (0): 2-14                            [1, 14, 1, 281]           [1, 28, 1, 281]           420                       [1, 1]
#   │    └─BatchNorm2d (1): 2-15                       [1, 28, 1, 281]           [1, 28, 1, 281]           56                        --
#   │    └─ELU (2): 2-16                               [1, 28, 1, 281]           [1, 28, 1, 281]           --                        --
#   │    └─AvgPool2d (3): 2-17                         [1, 28, 1, 281]           [1, 28, 1, 70]            --                        [1, 4]
#   │    └─Dropout (4): 2-18                           [1, 28, 1, 70]            [1, 28, 1, 70]            --                        --
#   ├─Flatten (flatten): 1-9                           [1, 28, 1, 70]            [1, 1960]                 --                        --
#   ├─Sequential (final_layer): 1-10                   [1, 1960]                 [1, 4]                    --                        --
#   │    └─Linear (clf): 2-19                          [1, 1960]                 [1, 4]                    7,844                     --
#   │    └─LogSoftmax (out_fun): 2-20                  [1, 4]                    [1, 4]                    --                        --
#   ======================================================================================================================================================
#   Total params: 10,028
#   Trainable params: 10,028
#   Non-trainable params: 0
#   Total mult-adds (M): 17.23
#   ======================================================================================================================================================
#   Input size (MB): 0.10
#   Forward/backward pass size (MB): 6.43
#   Params size (MB): 0.04
#   Estimated Total Size (MB): 6.56
#   ======================================================================================================================================================,
# )

# %%
loss = []
acc = []
for a in eegitnet.history:
    loss.append(a['train_loss'])    
    acc.append(a['train_accuracy'])
plt.plot(loss, label='Training Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()
plt.plot(acc, label='Training Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
eegitnet.score(X_test, np.argmax(y_test, axis=1))
# Out:
# 0.6481481481481481

# %%
test_metrics(eegitnet)
# Out:
# Accuracy:  0.6481481481481481
# Precision:  0.6533657015352882
# Recall:  0.6481481481481481
# F1:  0.6470187842079506

# %%
from EEGModels import *

# %%
X_train.shape
# Out:
# (4320, 22, 1125)

# %%
fusion = EEGNet_fusion(nb_classes=4, Chans=22, Samples=1125,
                  dropoutRate=0.5, norm_rate=0.25, dropoutType='Dropout', cpu=True)
fusion.compile(optimizer=keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
fusion, fusion_results = CV_train(fusion, torch.tensor([X_train, X_train, X_train]), X_test, n_epochs=1)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[48], line 4
#       1 fusion = EEGNet_fusion(nb_classes=4, Chans=22, Samples=1125,
#       2                   dropoutRate=0.5, norm_rate=0.25, dropoutType='Dropout', cpu=True)
#       3 fusion.compile(optimizer=keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# ----> 4 fusion, fusion_results = CV_train(fusion, torch.tensor([X_train, X_train, X_train]), X_test, n_epochs=1)
#
# Cell In[35], line 17, in CV_train(model, X, X_test, cnn, convlstm, batch_size, n_epochs, y_out, y_out_test)
#      14 label_train, _ = y_out[train_idx], y_out[val_idx]
#      15 y_train, y_val = y_out[train_idx], y_out[val_idx]
# ---> 17 X_train = X[train_idx]
#      18 X_val = X[val_idx]
#      20 if cnn:
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 1478062080000 bytes.

# %%
temp = X_train

# %%
X_train = X_train.transpose(0,2,1)

# %%
X_train.shape
# Out:
# (4320, 1125, 22)

# %%
fusion = EEGNet_fusion_V2(nb_classes=4, Chans=22, Samples=1125,
                  dropoutRate=0.5, norm_rate=0.25, dropoutType='Dropout', cpu=True)
fusion.compile(optimizer=keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
fusion, fusion_results = CV_train(fusion, torch.tensor([X_train, X_train, X_train, X_train, X_train]), X_test, n_epochs=1)
# Out:
# c:\Users\Sam\miniconda3\envs\pytgpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[53], line 4
#       1 fusion = EEGNet_fusion_V2(nb_classes=4, Chans=22, Samples=1125,
#       2                   dropoutRate=0.5, norm_rate=0.25, dropoutType='Dropout', cpu=True)
#       3 fusion.compile(optimizer=keras.optimizers.Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# ----> 4 fusion, fusion_results = CV_train(fusion, torch.tensor([X_train, X_train, X_train, X_train, X_train]), X_test, n_epochs=1)
#
# Cell In[35], line 17, in CV_train(model, X, X_test, cnn, convlstm, batch_size, n_epochs, y_out, y_out_test)
#      14 label_train, _ = y_out[train_idx], y_out[val_idx]
#      15 y_train, y_val = y_out[train_idx], y_out[val_idx]
# ---> 17 X_train = X[train_idx]
#      18 X_val = X[val_idx]
#      20 if cnn:
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 1478062080000 bytes.

# %%
dcn_results
# Out:
# {'Accuracy': [0.6030092592592593, 0.6099537037037037],
#  'F1': [0.5917885140072242, 0.5893488503579134],
#  'Precision': [0.6067420271467648, 0.6183133726738377],
#  'Recall': [0.6030092592592593, 0.6099537037037037]}

# %%
test_pred = dcn.predict(np.expand_dims(X_test_noise_2,-1))
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 15
# Out:
# 27/27 [==============================] - 1s 36ms/step
# Accuracy:  0.5891203703703703
# F1:  0.5777006594328525
# Precision:  0.6003727520351626
# Recall:  0.5891203703703703

# %%
test_pred = dcn.predict(np.expand_dims(X_test_noise,-1))
pred = (test_pred == test_pred.max(axis=1)[:,None]).astype(int)
print("Accuracy: ",accuracy_score(y_test.argmax(axis=1), pred.argmax(axis=1)))
print("F1: ",f1_score(y_test.argmax(axis=1), pred.argmax(axis=1), average='weighted'))
print("Precision: ",precision_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
print("Recall: ",recall_score(y_test.argmax(axis=1), pred.argmax(axis=1),average='weighted'))
## SNR 8
# Out:
# 27/27 [==============================] - 1s 38ms/step
# Accuracy:  0.5590277777777778
# F1:  0.547928522428475
# Precision:  0.5876595148909717
# Recall:  0.5590277777777778

# %%
dcn.save('models/dcn.h5')

# %%
dcn = keras.models.load_model('models/dcn.h5')
